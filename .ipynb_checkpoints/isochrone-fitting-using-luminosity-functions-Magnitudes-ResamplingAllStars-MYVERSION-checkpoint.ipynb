# %%
# !jt -t  grade3

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as st
import scipy.interpolate as interp
from astropy.io.votable import parse_single_table
from __future__ import division
from scipy.stats import gaussian_kde
import popsims
from tqdm import tqdm
import matplotlib as mpl
import seaborn as sns
sns.set(style="ticks", context="talk")
#plt.style.use("dark_background")
mpl.rc('image', cmap='cividis')
WFIRSTlimits = [30.0,30.0] #limiting magnitudes used for WFIRS
# %matplotlib inline
# Out:
# Adding 89 sources from /Users/caganze/research/splat//resources/Spectra/Public/MAGE/ to spectral database
# Adding 2404 sources from /Users/caganze/research/splat//resources/Spectra/Public/SPEX-PRISM/ to spectral database
# Adding 145 sources from /Users/caganze/research/splat//resources/Spectra/Public/LRIS-RED/ to spectral database

# %%
path_plot = '/users/caganze/research/stellarstreams/figures/isochrones/'
path_data = '/users/caganze/research/stellarstreams/data/isochrones/'

# %%
def kde(x, x_num, x_grid, bandwidth=0.2, **kwargs):
    """Kernel Density Estimation with Scipy"""
    x_tot = np.asarray([])
    for i in range(len(x)):
        x_tot = np.concatenate((x_tot, np.repeat(x[i], int(x_num[i]))), axis = 0)
    kde = gaussian_kde(x_tot)
    return kde.evaluate(x_grid)


def generate_rand_from_pdf(pdf, x_grid, num):
    cdf = np.cumsum(pdf)
    cdf = cdf / cdf[-1]
    values = np.random.rand(num)
    value_bins = np.searchsorted(cdf, values)
    random_from_cdf = x_grid[value_bins]
    return random_from_cdf

# %% [markdown]
# DO for WFIRST on M31 field 10-20 kpc

# %%
## Load the PANDAS field corrected to magnitudes in R and Z WFIRST filters: location, R, Z, and metallicity.
locIn = np.loadtxt(path_data+'/WFIfilters_FromPANDAS_g0limit25.5_ZRcorrection_RAdec_M31_10_20kpc_new.vot.txt', skiprows = 1, usecols = [4,5])
magsIn = np.loadtxt(path_data+'/WFIfilters_FromPANDAS_g0limit25.5_ZRcorrection_RAdec_M31_10_20kpc_new.vot.txt', skiprows = 1, usecols = [0,1])
fehIn = np.loadtxt(path_data+'/WFIfilters_FromPANDAS_g0limit25.5_ZRcorrection_RAdec_M31_10_20kpc_new.vot.txt', skiprows = 1, usecols = [6])

## load the 16 isochrones that we use to fit the stars to
isos = np.loadtxt(path_data+'/WFIRST_PARSEC_isochrones_grid.txt')
#dist_mod_And = 16.8553 + 7.6 #Sarah's old estimate for Andromeda
dist_mod_And = 24.47 #from Ibata+2014

# %%
## know where new ischrones start in the "isos" isochrone-grid (different ages and different metallicities)
all_iso = []
start_feh = [0,0,0,0]
start_age = np.repeat(0,16)
j_feh = 1
j_age = 1
for i in range(len(isos[:,0])-1):
    if (isos[i+1,0] != isos[i,0]):
        start_feh[j_feh] = i+1
        j_feh = j_feh + 1
    if (isos[i+1,1] != isos[i,1]):
        start_age[j_age] = i+1
        j_age = j_age + 1

# %%
fig, ax=plt.subplots()
for j in range(15):
    _= ax.scatter((isos[start_age[j]:start_age[j+1],10]-isos[start_age[j]:start_age[j+1],11]), 
            isos[start_age[j]:start_age[j+1],11] + dist_mod_And, s = 3, marker='+')

ax.set(xlabel='R - Z', ylabel='Z')
ax.invert_yaxis()

# %%
fehIn
# Out:
# array([-0.628    , -0.992    , -1.109    , ...,  9.9899998, -1.13     ,
#         0.466    ])

# %%
#double check the metallicities with the convention that we use (solar is 0.0152)
print (np.log10(isos[start_feh,0]/0.0152))
# Out:
# [-2.49023171 -1.49052334 -0.49801336  0.43638238]

# %%
fig, ax=plt.subplots()
c=ax.scatter(locIn[:,0], locIn[:,1], s=.05, c=fehIn , cmap='cividis')
cbar=plt.colorbar(c)
cbar.ax.set(ylabel='Fe/H')
ax.set(xlabel='RA', ylabel='Dec')
# Out:
# [Text(0.5, 0, 'RA'), Text(0, 0.5, 'Dec')]

# %%
#magsIn[:,]

# %%
fig, ax=plt.subplots()
c=ax.scatter(magsIn[:,0]-magsIn[:,1], magsIn[:,1], s=.05, c=fehIn , cmap='cividis')
cbar=plt.colorbar(c)
cbar.ax.set(ylabel='Fe/H')
ax.set(xlabel='R-Z', ylabel='Z')
# Out:
# [Text(0.5, 0, 'R-Z'), Text(0, 0.5, 'Z')]

# %%
##For every star in PANDAS (in the list magsIn): 
## estimate the distance to the points of all isochrones, in 2D: color and Z magnitude
## and assign the metallicity and age of the closest isochrone
## Also assign at what distance the isochrone is put: M31 distance (0) or closer, i.e. MW disk or halo: > 0.
## We need to include isochrones for the MW disk and halo, because there still is quite some contamination in the PANDAS fields

match = np.zeros(len(magsIn[:,0]))
matchFeH = np.zeros(len(magsIn[:,0]))
matchAge = np.zeros(len(magsIn[:,0]))
matchgal = np.zeros(len(magsIn[:,0]))
print (len(match), len(isos[:,13]))
range1 = np.max(np.concatenate((magsIn[:,1], isos[:,11] + dist_mod_And,
                                isos[:,11] + 8, isos[:,11] + 10, isos[:,11] + 12, isos[:,11] + 14,
                                isos[:,11] + 16, isos[:,11] + 18, isos[:,11] + 20), axis=0))
- np.min(np.concatenate((magsIn[:,1], isos[:,11] + dist_mod_And,
                         isos[:,11] + 8, isos[:,11] + 10, isos[:,11] + 12, isos[:,11] + 14,
                         isos[:,11] + 16, isos[:,11] + 18, isos[:,11] + 20), axis=0))
range2 = np.max(np.concatenate((magsIn[:,0]-magsIn[:,1], isos[:,10]-isos[:,11], isos[:,10]-isos[:,11], 
                                isos[:,10]-isos[:,11], isos[:,10]-isos[:,11], isos[:,10]-isos[:,11], 
                                isos[:,10]-isos[:,11], isos[:,10]-isos[:,11], isos[:,10]-isos[:,11]), axis=0))
- np.min(np.concatenate((magsIn[:,0]-magsIn[:,1], isos[:,10]-isos[:,11], isos[:,10]-isos[:,11], 
                         isos[:,10]-isos[:,11], isos[:,10]-isos[:,11], isos[:,10]-isos[:,11],
                         isos[:,10]-isos[:,11], isos[:,10]-isos[:,11], isos[:,10]-isos[:,11]), axis=0))
for i in range(len(magsIn[:,0])):
    rescale_dist1 = (magsIn[i,1] - np.concatenate((isos[:,11] + dist_mod_And,
                                isos[:,11] + 8, isos[:,11] + 10, isos[:,11] + 12, isos[:,11] + 14,
                                isos[:,11] + 16, isos[:,11] + 18, isos[:,11] + 20), axis=0)) / range1
    rescale_dist2 = ((magsIn[i,0]-magsIn[i,1]) - np.concatenate((isos[:,10]-isos[:,11], isos[:,10]-isos[:,11], 
                                isos[:,10]-isos[:,11], isos[:,10]-isos[:,11], isos[:,10]-isos[:,11], 
                                isos[:,10]-isos[:,11], isos[:,10]-isos[:,11], isos[:,10]-isos[:,11]), axis=0)) / range2
    match[i] = np.argmin(np.sqrt(rescale_dist1**2 + rescale_dist2**2))
    if np.logical_and(match[i] < start_age[1], match[i] >= start_age[0]):
        matchFeH[i] = isos[np.asarray(start_feh),0][0]
        matchAge[i] = isos[np.asarray(start_age),1][0]
        matchgal[i] = 0
    elif np.logical_and(match[i] < start_age[2], match[i] >= start_age[1]):
        matchFeH[i] = isos[np.asarray(start_feh),0][0]
        matchAge[i] = isos[np.asarray(start_age),1][1]
        matchgal[i] = 0
    elif np.logical_and(match[i] < start_age[3], match[i] >= start_age[2]):
        matchFeH[i] = isos[np.asarray(start_feh),0][0]
        matchAge[i] = isos[np.asarray(start_age),1][2]
        matchgal[i] = 0
    elif np.logical_and(match[i] < start_age[4], match[i] >= start_age[3]):
        matchFeH[i] = isos[np.asarray(start_feh),0][0]
        matchAge[i] = isos[np.asarray(start_age),1][3]
        matchgal[i] = 0
    elif np.logical_and(match[i] < start_age[5], match[i] >= start_age[4]):
        matchFeH[i] = isos[np.asarray(start_feh),0][1]
        matchAge[i] = isos[np.asarray(start_age),1][0]
        matchgal[i] = 0
    elif np.logical_and(match[i] < start_age[6], match[i] >= start_age[5]):
        matchFeH[i] = isos[np.asarray(start_feh),0][1]
        matchAge[i] = isos[np.asarray(start_age),1][1]
        matchgal[i] = 0
    elif np.logical_and(match[i] < start_age[7], match[i] >= start_age[6]):
        matchFeH[i] = isos[np.asarray(start_feh),0][1]
        matchAge[i] = isos[np.asarray(start_age),1][2]
        matchgal[i] = 0
    elif np.logical_and(match[i] < start_age[8], match[i] >= start_age[7]):
        matchFeH[i] = isos[np.asarray(start_feh),0][1]
        matchAge[i] = isos[np.asarray(start_age),1][3]
        matchgal[i] = 0
    elif np.logical_and(match[i] < start_age[9], match[i] >= start_age[8]):
        matchFeH[i] = isos[np.asarray(start_feh),0][2]
        matchAge[i] = isos[np.asarray(start_age),1][0]
        matchgal[i] = 0
    elif np.logical_and(match[i] < start_age[10], match[i] >= start_age[9]):
        matchFeH[i] = isos[np.asarray(start_feh),0][2]
        matchAge[i] = isos[np.asarray(start_age),1][1]
        matchgal[i] = 0
    elif np.logical_and(match[i] < start_age[11], match[i] >= start_age[10]):
        matchFeH[i] = isos[np.asarray(start_feh),0][2]
        matchAge[i] = isos[np.asarray(start_age),1][2]
        matchgal[i] = 0
    elif np.logical_and(match[i] < start_age[12], match[i] >= start_age[11]):
        matchFeH[i] = isos[np.asarray(start_feh),0][2]
        matchAge[i] = isos[np.asarray(start_age),1][3]
        matchgal[i] = 0
    elif np.logical_and(match[i] < start_age[13], match[i] >= start_age[12]):
        matchFeH[i] = isos[np.asarray(start_feh),0][3]
        matchAge[i] = isos[np.asarray(start_age),1][0]
        matchgal[i] = 0
    elif np.logical_and(match[i] < start_age[14], match[i] >= start_age[13]):
        matchFeH[i] = isos[np.asarray(start_feh),0][3]
        matchAge[i] = isos[np.asarray(start_age),1][1]
        matchgal[i] = 0
    elif np.logical_and(match[i] < start_age[15], match[i] >= start_age[14]):
        matchFeH[i] = isos[np.asarray(start_feh),0][3]
        matchAge[i] = isos[np.asarray(start_age),1][2]
        matchgal[i] = 0
    elif np.logical_and(match[i] < len(isos[:,13]), match[i] >= start_age[15]):
        matchFeH[i] = isos[np.asarray(start_feh),0][3]
        matchAge[i] = isos[np.asarray(start_age),1][3]
        matchgal[i] = 0
    elif match[i] > len(isos[:,13]) + start_age[0]:
        MWmatch = match[i] % len(isos[:,13])
        if np.logical_and(MWmatch < start_age[1], MWmatch > start_age[0]):
            matchFeH[i] = isos[np.asarray(start_feh),0][0]
            matchAge[i] = isos[np.asarray(start_age),1][0]
            matchgal[i] = np.round(match[i] / len(isos[:,13])).astype('int')
        elif np.logical_and(MWmatch < start_age[2], MWmatch > start_age[1]):
            matchFeH[i] = isos[np.asarray(start_feh),0][0]
            matchAge[i] = isos[np.asarray(start_age),1][1]
            matchgal[i] = np.round(match[i] / len(isos[:,13])).astype('int')
        elif np.logical_and(MWmatch < start_age[3], MWmatch > start_age[2]):
            matchFeH[i] = isos[np.asarray(start_feh),0][0]
            matchAge[i] = isos[np.asarray(start_age),1][2]
            matchgal[i] = np.round(match[i] / len(isos[:,13])).astype('int')
        elif np.logical_and(MWmatch < start_age[4], MWmatch > start_age[3]):
            matchFeH[i] = isos[np.asarray(start_feh),0][0]
            matchAge[i] = isos[np.asarray(start_age),1][3]
            matchgal[i] = np.round(match[i] / len(isos[:,13])).astype('int')
        elif np.logical_and(MWmatch < start_age[5], MWmatch > start_age[4]):
            matchFeH[i] = isos[np.asarray(start_feh),0][1]
            matchAge[i] = isos[np.asarray(start_age),1][0]
            matchgal[i] = np.round(match[i] / len(isos[:,13])).astype('int')
        elif np.logical_and(MWmatch < start_age[6], MWmatch > start_age[5]):
            matchFeH[i] = isos[np.asarray(start_feh),0][1]
            matchAge[i] = isos[np.asarray(start_age),1][1]
            matchgal[i] = np.round(match[i] / len(isos[:,13])).astype('int')
        elif np.logical_and(MWmatch < start_age[7], MWmatch > start_age[6]):
            matchFeH[i] = isos[np.asarray(start_feh),0][1]
            matchAge[i] = isos[np.asarray(start_age),1][2]
            matchgal[i] = np.round(match[i] / len(isos[:,13])).astype('int')
        elif np.logical_and(MWmatch < start_age[8], MWmatch > start_age[7]):
            matchFeH[i] = isos[np.asarray(start_feh),0][1]
            matchAge[i] = isos[np.asarray(start_age),1][3]
            matchgal[i] = np.round(match[i] / len(isos[:,13])).astype('int')
        elif np.logical_and(MWmatch < start_age[9], MWmatch > start_age[8]):
            matchFeH[i] = isos[np.asarray(start_feh),0][2]
            matchAge[i] = isos[np.asarray(start_age),1][0]
            matchgal[i] = np.round(match[i] / len(isos[:,13])).astype('int')
        elif np.logical_and(MWmatch < start_age[10], MWmatch > start_age[9]):
            matchFeH[i] = isos[np.asarray(start_feh),0][2]
            matchAge[i] = isos[np.asarray(start_age),1][1]
            matchgal[i] = np.round(match[i] / len(isos[:,13])).astype('int')
        elif np.logical_and(MWmatch < start_age[11], MWmatch > start_age[10]):
            matchFeH[i] = isos[np.asarray(start_feh),0][2]
            matchAge[i] = isos[np.asarray(start_age),1][2]
            matchgal[i] = np.round(match[i] / len(isos[:,13])).astype('int')
        elif np.logical_and(MWmatch < start_age[12], MWmatch > start_age[11]):
            matchFeH[i] = isos[np.asarray(start_feh),0][2]
            matchAge[i] = isos[np.asarray(start_age),1][3]
            matchgal[i] = np.round(match[i] / len(isos[:,13])).astype('int')
        elif np.logical_and(MWmatch < start_age[13], MWmatch > start_age[12]):
            matchFeH[i] = isos[np.asarray(start_feh),0][3]
            matchAge[i] = isos[np.asarray(start_age),1][0]
            matchgal[i] = np.round(match[i] / len(isos[:,13])).astype('int')
        elif np.logical_and(MWmatch < start_age[14], MWmatch > start_age[13]):
            matchFeH[i] = isos[np.asarray(start_feh),0][3]
            matchAge[i] = isos[np.asarray(start_age),1][1]
            matchgal[i] = np.round(match[i] / len(isos[:,13])).astype('int')
        elif np.logical_and(MWmatch < start_age[15], MWmatch > start_age[14]):
            matchFeH[i] = isos[np.asarray(start_feh),0][3]
            matchAge[i] = isos[np.asarray(start_age),1][2]
            matchgal[i] = np.round(match[i] / len(isos[:,13])).astype('int')
        elif np.logical_and(MWmatch < len(isos[:,13]), match[i] >= len(isos[:,13]) + start_age[15]):
            matchFeH[i] = isos[np.asarray(start_feh),0][3]
            matchAge[i] = isos[np.asarray(start_age),1][3]
            matchgal[i] = np.round(match[i] / len(isos[:,13])).astype('int')

        
print ("number of stars matched to FeH of isochrones:")
print (isos[np.asarray(start_feh),0][0], np.sum(matchFeH == isos[np.asarray(start_feh),0][0]))
print (isos[np.asarray(start_feh),0][1], np.sum(matchFeH == isos[np.asarray(start_feh),0][1]))
print (isos[np.asarray(start_feh),0][2], np.sum(matchFeH == isos[np.asarray(start_feh),0][2]))
print (isos[np.asarray(start_feh),0][3], np.sum(matchFeH == isos[np.asarray(start_feh),0][3]))
print ("number of stars matched to Age of isochrones:")
print (10.0**isos[np.asarray(start_age),1][0]/1e9, np.sum(matchAge == isos[np.asarray(start_age),1][0]))
print (10.0**isos[np.asarray(start_age),1][1]/1e9, np.sum(matchAge == isos[np.asarray(start_age),1][1]))
print (10.0**isos[np.asarray(start_age),1][2]/1e9, np.sum(matchAge == isos[np.asarray(start_age),1][2]))
print (10.0**isos[np.asarray(start_age),1][3]/1e9, np.sum(matchAge == isos[np.asarray(start_age),1][3]))

print ("galaxy")
print ("MW", np.sum(matchgal >= 1))
print ("M31", np.sum(matchgal == 0))
# Out:
# 171656 3886
# number of stars matched to FeH of isochrones:
# 4.916e-05 32470
# 0.00049127 21413
# 0.0048287 59652
# 0.041517 56971
# number of stars matched to Age of isochrones:
# 8.491804750363144 50178
# 9.506047936562808 26554
# 10.49542428652324 27551
# 11.508003889444357 66223
# galaxy
# MW 100410
# M31 71246

# %%
## Plot for each age and metallicity the isochrones at differernt distances, and the stars assigned to those isochrones.
## Note how many stars are assigned to these isochrones, 
## and how many of those to the M31-isochrone of this age and metallicity

fig, axes = plt.subplots(4,4, figsize = [20,20])
for j in range(16):
    axes[j%4,int(j/4)].hist2d((magsIn[np.logical_and(matchFeH == isos[np.asarray(start_feh),0][int(j/4)], 
                                      matchAge == isos[np.asarray(start_age),1][j%4]),0]
                -magsIn[np.logical_and(matchFeH == isos[np.asarray(start_feh),0][int(j/4)], 
                                      matchAge == isos[np.asarray(start_age),1][j%4]),1]), 
               magsIn[np.logical_and(matchFeH == isos[np.asarray(start_feh),0][int(j/4)], 
                                      matchAge == isos[np.asarray(start_age),1][j%4]),1], 
               bins = 50, range = [[-1,4],[17,25]])
    if j == 15:
        axes[j%4,int(j/4)].scatter((isos[start_age[j]:,10]-isos[start_age[j]:,11]), 
            isos[start_age[j]:,11]  + dist_mod_And, s = 2)
        axes[j%4,int(j/4)].scatter((isos[start_age[j]:,10]-isos[start_age[j]:,11]), 
            isos[start_age[j]:,11]  + 8, s = 2)
        axes[j%4,int(j/4)].scatter((isos[start_age[j]:,10]-isos[start_age[j]:,11]), 
            isos[start_age[j]:,11]  + 10, s = 2)
        axes[j%4,int(j/4)].scatter((isos[start_age[j]:,10]-isos[start_age[j]:,11]), 
            isos[start_age[j]:,11]  + 12, s = 2)
        axes[j%4,int(j/4)].scatter((isos[start_age[j]:,10]-isos[start_age[j]:,11]), 
            isos[start_age[j]:,11]  + 14, s = 2)        
        axes[j%4,int(j/4)].scatter((isos[start_age[j]:,10]-isos[start_age[j]:,11]), 
            isos[start_age[j]:,11]  + 16, s = 2)        
        axes[j%4,int(j/4)].scatter((isos[start_age[j]:,10]-isos[start_age[j]:,11]), 
            isos[start_age[j]:,11]  + 18, s = 2)       
        axes[j%4,int(j/4)].scatter((isos[start_age[j]:,10]-isos[start_age[j]:,11]), 
            isos[start_age[j]:,11]  + 20, s = 2)       
    else:
        axes[j%4,int(j/4)].scatter((isos[start_age[j]:start_age[j+1],10]-isos[start_age[j]:start_age[j+1],11]), 
            isos[start_age[j]:start_age[j+1],11] + dist_mod_And, s = 2)
        axes[j%4,int(j/4)].scatter((isos[start_age[j]:start_age[j+1],10]-isos[start_age[j]:start_age[j+1],11]), 
            isos[start_age[j]:start_age[j+1],11] + 8, s = 2)
        axes[j%4,int(j/4)].scatter((isos[start_age[j]:start_age[j+1],10]-isos[start_age[j]:start_age[j+1],11]), 
            isos[start_age[j]:start_age[j+1],11] + 10, s = 2)
        axes[j%4,int(j/4)].scatter((isos[start_age[j]:start_age[j+1],10]-isos[start_age[j]:start_age[j+1],11]), 
            isos[start_age[j]:start_age[j+1],11] + 12, s = 2)
        axes[j%4,int(j/4)].scatter((isos[start_age[j]:start_age[j+1],10]-isos[start_age[j]:start_age[j+1],11]), 
            isos[start_age[j]:start_age[j+1],11] + 14, s = 2)
        axes[j%4,int(j/4)].scatter((isos[start_age[j]:start_age[j+1],10]-isos[start_age[j]:start_age[j+1],11]), 
            isos[start_age[j]:start_age[j+1],11] + 16, s = 2)
        axes[j%4,int(j/4)].scatter((isos[start_age[j]:start_age[j+1],10]-isos[start_age[j]:start_age[j+1],11]), 
            isos[start_age[j]:start_age[j+1],11] + 18, s = 2)
        axes[j%4,int(j/4)].scatter((isos[start_age[j]:start_age[j+1],10]-isos[start_age[j]:start_age[j+1],11]), 
            isos[start_age[j]:start_age[j+1],11] + 20, s = 2)
    axes[j%4,int(j/4)].text(2,23.5,'[Fe/H] = %0.1e' %(np.log10(isos[np.asarray(start_feh),0][int(j/4)]/0.0152)), color = 'white')
    axes[j%4,int(j/4)].text(2,24,'age = %0.1f Gyr' %(10.0**isos[np.asarray(start_age),1][j%4]/1e9), color = 'white')
    axes[j%4,int(j/4)].text(2,24.5,'# stars = %d' %(np.sum(np.logical_and(matchFeH == isos[np.asarray(start_feh),0][int(j/4)], 
                                      matchAge == isos[np.asarray(start_age),1][j%4]))), color = 'white')
    axes[j%4,int(j/4)].text(2,25,'# stars And = %d' %(np.sum(np.logical_and(np.logical_and(matchFeH == isos[np.asarray(start_feh),0][int(j/4)], 
                                      matchAge == isos[np.asarray(start_age),1][j%4]), matchgal == 0))), color = 'white')
    axes[j%4,int(j/4)].set_xlabel('R - Z')
    axes[j%4,int(j/4)].set_ylabel('Z')
    axes[j%4,int(j/4)].axis([-1,4,25,17])
    plt.tight_layout()

# %%
## read in all WFIRST bands from the isochrone grid
wfirst_mags = np.loadtxt(path_data+'/WFIRST_PARSEC_isochrones_grid.txt', skiprows = 12, usecols = [10,11,12,13,14,15])
oldstars = np.concatenate((locIn, np.reshape(magsIn, (len(magsIn),2)), np.reshape(fehIn, (len(fehIn),1))), axis=1)
newstars = np.asarray([])

## Go through all different distances used
for i in range(8):
    if i == 0: dist_mod = dist_mod_And #M31
    elif i >= 1: dist_mod = 6 + 2*i #MW disk, inner halo, and outer halo
    ## go through all metallicities and ages for this distance
    for j in range(16):
        start_isochrone = start_age[j]
        if j == len(start_age)-1:
            end_isochrone = len(wfirst_mags[:,0])-1
        else:
            end_isochrone = start_age[j+1]-1
        inter_Rmags = interp.interp1d(wfirst_mags[start_isochrone:end_isochrone,1], 
                        wfirst_mags[start_isochrone:end_isochrone,0], assume_sorted = False, fill_value = "extrapolate")
        inter_Ymags = interp.interp1d(wfirst_mags[start_isochrone:end_isochrone,1], 
                        wfirst_mags[start_isochrone:end_isochrone,2], assume_sorted = False, fill_value = "extrapolate")
        inter_Jmags = interp.interp1d(wfirst_mags[start_isochrone:end_isochrone,1], 
                        wfirst_mags[start_isochrone:end_isochrone,3], assume_sorted = False, fill_value = "extrapolate")
        inter_Hmags = interp.interp1d(wfirst_mags[start_isochrone:end_isochrone,1], 
                        wfirst_mags[start_isochrone:end_isochrone,4], assume_sorted = False, fill_value = "extrapolate")
        inter_Fmags = interp.interp1d(wfirst_mags[start_isochrone:end_isochrone,1], 
                        wfirst_mags[start_isochrone:end_isochrone,5], assume_sorted = False, fill_value = "extrapolate")
        ## read in the luminosity function in all WFIRST bands for this metallicity and age - isochrone
        ## the luminosity functions are created drawing 1e5 stars from an IMF for this isochrone
        lumfunc = np.loadtxt(path_data+'/WFIRST_PARSEC_lumfunc_isochrone%d_allbands.txt' %j)
        ## count the number of stars assigned to this isochrone (distance, age, metallicity)
        numstars = np.sum(np.logical_and(np.logical_and(matchFeH == isos[np.asarray(start_feh),0][int(j/4)],
                                      matchAge == isos[np.asarray(start_age),1][j%4]), matchgal == i))
        print ('i = ', i, '# stars in isochrone:', j, numstars)
        feh = isos[np.asarray(start_feh),0][int(j/4)]
        limits = [np.max(magsIn[:,0]), np.max(magsIn[:,1])]
        if numstars > 0:
            ## check how many stars (of the 1e5 total) there are in the luminosity function within the PANDAS limits.
            numunderlim = np.asarray([np.sum(lumfunc[lumfunc[:,0] + dist_mod < limits[0],1]), 
                np.sum(lumfunc[lumfunc[:,2] + dist_mod < limits[1],3])])
            #print 'number of 1e5 stars luminosity function under old limits of', limits, ':', numunderlim
            
            ## check how many stars (of the 1e5 total) there should be in the luminosity function within the WFIRST limits.
            newnumunderlim = np.asarray([np.sum(lumfunc[lumfunc[:,0] + dist_mod < WFIRSTlimits[0],1]), 
                np.sum(lumfunc[lumfunc[:,2] + dist_mod < WFIRSTlimits[1],3])])
            #print 'number of 1e5 stars luminosity function under new limits of', WFIRSTlimits, ':',  newnumunderlim
            
            ## calculate how many stars need to be added for the WFIRST limits, 
            ## using the relative number of stars in the luminosity function within the WFIRST and PANDAS limits,
            ## and the number of stars matched to this isochrone in the PANDAS data
            newnumstars = np.round(numstars*newnumunderlim[1]*1.0/numunderlim[1]).astype('int')
            newnumstars0 = np.round(numstars*newnumunderlim[0]*1.0/numunderlim[0]).astype('int')
            print ("newnumstars R and Z: ", newnumstars0, newnumstars)
            addstars = newnumstars - numstars
            print (" need to add stars: ", addstars, "to", newnumstars)
            ## Estimate the KDE of the Z magnitude from the PANDAS stars over the Z-magnitude from the isochrone
            ## and randomly draw all stars (not just the added ones) from the KDE
            x_grid_Z = np.linspace(np.min(wfirst_mags[start_isochrone:end_isochrone,1] + dist_mod), 
                                   np.min([WFIRSTlimits[1], np.max(wfirst_mags[start_isochrone:end_isochrone,1]) + dist_mod]), 
                                   newnumstars)
            kdepdf_Z = kde(lumfunc[lumfunc[:,2] + dist_mod < WFIRSTlimits[1],2] + dist_mod,
                       lumfunc[lumfunc[:,2] + dist_mod < WFIRSTlimits[1],3], x_grid_Z)
            random_Z = generate_rand_from_pdf(kdepdf_Z, x_grid_Z, newnumstars)
            ## Use the interpolate relation between Z and other bands from the isochrone to 
            ## estimate the other magnitudes for all new stars
            random_R = inter_Rmags(random_Z - dist_mod) + dist_mod
            random_H = inter_Hmags(random_Z - dist_mod) + dist_mod
            random_Y = inter_Ymags(random_Z - dist_mod) + dist_mod
            random_J = inter_Jmags(random_Z - dist_mod) + dist_mod
            random_F = inter_Fmags(random_Z - dist_mod) + dist_mod
            ## randomly assign position (xki and eta) for all new stars
            random_xki = np.random.uniform(low = np.min(locIn[:,0]), high = np.max(locIn[:,0]), size = newnumstars)
            random_eta = np.random.uniform(low = np.min(locIn[:,1]), high = np.max(locIn[:,1]), size = newnumstars)
            if newstars.size == 0:
                newstars = np.concatenate((np.reshape(random_xki, (len(random_xki),1)), 
                                        np.reshape(random_eta, (len(random_eta),1)), 
                                        np.reshape(random_R, (len(random_R),1)), 
                                        np.reshape(random_Z, (len(random_Z),1)), 
                                        np.reshape(random_Y, (len(random_Y),1)), 
                                        np.reshape(random_J, (len(random_J),1)),
                                        np.reshape(random_H, (len(random_H),1)), 
                                        np.reshape(random_F, (len(random_F),1)),
                                        np.reshape(np.repeat(np.log10(feh*1.0/0.0152), len(random_xki))
                                                , (len(random_xki),1))), axis = 1)
            else:
                newstars = np.concatenate((newstars, np.concatenate((np.reshape(random_xki, (len(random_xki),1)), 
                                        np.reshape(random_eta, (len(random_eta),1)), 
                                        np.reshape(random_R, (len(random_R),1)), 
                                        np.reshape(random_Z, (len(random_Z),1)), 
                                        np.reshape(random_Y, (len(random_Y),1)), 
                                        np.reshape(random_J, (len(random_J),1)),
                                        np.reshape(random_H, (len(random_H),1)), 
                                        np.reshape(random_F, (len(random_F),1)),
                                        np.reshape(np.repeat(np.log10(feh*1.0/0.0152), len(random_xki))
                                                , (len(random_xki),1))), axis = 1)), axis = 0)
            print ('new number of stars in isochrone under new limits', newnumstars, ':', addstars, "added")


#newstars = np.asarray(newstars)
print (np.shape(newstars))
print (len(newstars[:,0]), len(oldstars[:,0]))
# Out:
# i =  0 # stars in isochrone: 0 4513
# newnumstars R and Z:  176919 145144
#  need to add stars:  140631 to 145144
# new number of stars in isochrone under new limits 145144 : 140631 added
# i =  0 # stars in isochrone: 1 2853
# newnumstars R and Z:  109166 100187
#  need to add stars:  97334 to 100187
# new number of stars in isochrone under new limits 100187 : 97334 added
# i =  0 # stars in isochrone: 2 3957
# newnumstars R and Z:  152385 128937
#  need to add stars:  124980 to 128937
# new number of stars in isochrone under new limits 128937 : 124980 added
# i =  0 # stars in isochrone: 3 8130
# newnumstars R and Z:  312429 266140
#  need to add stars:  258010 to 266140
# new number of stars in isochrone under new limits 266140 : 258010 added
# i =  0 # stars in isochrone: 4 2583
# newnumstars R and Z:  104018 91942
#  need to add stars:  89359 to 91942
# new number of stars in isochrone under new limits 91942 : 89359 added
# i =  0 # stars in isochrone: 5 1879
# newnumstars R and Z:  75296 68449
#  need to add stars:  66570 to 68449
# new number of stars in isochrone under new limits 68449 : 66570 added
# i =  0 # stars in isochrone: 6 2222
# newnumstars R and Z:  89494 80985
#  need to add stars:  78763 to 80985
# new number of stars in isochrone under new limits 80985 : 78763 added
# i =  0 # stars in isochrone: 7 3060
# newnumstars R and Z:  122089 113405
#  need to add stars:  110345 to 113405
# new number of stars in isochrone under new limits 113405 : 110345 added
# i =  0 # stars in isochrone: 8 9681
# newnumstars R and Z:  378111 329063
#  need to add stars:  319382 to 329063
# new number of stars in isochrone under new limits 329063 : 319382 added
# i =  0 # stars in isochrone: 9 3795
# newnumstars R and Z:  151289 133217
#  need to add stars:  129422 to 133217
# new number of stars in isochrone under new limits 133217 : 129422 added
# i =  0 # stars in isochrone: 10 4129
# newnumstars R and Z:  172201 150865
#  need to add stars:  146736 to 150865
# new number of stars in isochrone under new limits 150865 : 146736 added
# i =  0 # stars in isochrone: 11 15754
# newnumstars R and Z:  642576 579512
#  need to add stars:  563758 to 579512
# new number of stars in isochrone under new limits 579512 : 563758 added
# i =  0 # stars in isochrone: 12 4767
# newnumstars R and Z:  199572 174784
#  need to add stars:  170017 to 174784
# new number of stars in isochrone under new limits 174784 : 170017 added
# i =  0 # stars in isochrone: 13 1448
# newnumstars R and Z:  63242 55651
#  need to add stars:  54203 to 55651
# new number of stars in isochrone under new limits 55651 : 54203 added
# i =  0 # stars in isochrone: 14 669
# newnumstars R and Z:  28923 25051
#  need to add stars:  24382 to 25051
# new number of stars in isochrone under new limits 25051 : 24382 added
# i =  0 # stars in isochrone: 15 656
# newnumstars R and Z:  26555 24781
#  need to add stars:  24125 to 24781
# new number of stars in isochrone under new limits 24781 : 24125 added
# i =  1 # stars in isochrone: 0 12
# newnumstars R and Z:  12 12
#  need to add stars:  0 to 12
# new number of stars in isochrone under new limits 12 : 0 added
# i =  1 # stars in isochrone: 1 7
# newnumstars R and Z:  7 7
#  need to add stars:  0 to 7
# new number of stars in isochrone under new limits 7 : 0 added
# i =  1 # stars in isochrone: 2 2
# newnumstars R and Z:  2 2
#  need to add stars:  0 to 2
# new number of stars in isochrone under new limits 2 : 0 added
# i =  1 # stars in isochrone: 3 11
# newnumstars R and Z:  11 11
#  need to add stars:  0 to 11
# new number of stars in isochrone under new limits 11 : 0 added
# i =  1 # stars in isochrone: 4 11
# newnumstars R and Z:  11 11
#  need to add stars:  0 to 11
# new number of stars in isochrone under new limits 11 : 0 added
# i =  1 # stars in isochrone: 5 0
# i =  1 # stars in isochrone: 6 3
# newnumstars R and Z:  3 3
#  need to add stars:  0 to 3
# new number of stars in isochrone under new limits 3 : 0 added
# i =  1 # stars in isochrone: 7 9
# newnumstars R and Z:  9 9
#  need to add stars:  0 to 9
# new number of stars in isochrone under new limits 9 : 0 added
# i =  1 # stars in isochrone: 8 216
# newnumstars R and Z:  216 216
#  need to add stars:  0 to 216
# new number of stars in isochrone under new limits 216 : 0 added
# i =  1 # stars in isochrone: 9 0
# i =  1 # stars in isochrone: 10 0
# i =  1 # stars in isochrone: 11 0
# i =  1 # stars in isochrone: 12 0
# i =  1 # stars in isochrone: 13 0
# i =  1 # stars in isochrone: 14 0
# i =  1 # stars in isochrone: 15 0
# i =  2 # stars in isochrone: 0 25
# newnumstars R and Z:  25 25
#  need to add stars:  0 to 25
# new number of stars in isochrone under new limits 25 : 0 added
# i =  2 # stars in isochrone: 1 12
# newnumstars R and Z:  12 12
#  need to add stars:  0 to 12
# new number of stars in isochrone under new limits 12 : 0 added
# i =  2 # stars in isochrone: 2 4
# newnumstars R and Z:  4 4
#  need to add stars:  0 to 4
# new number of stars in isochrone under new limits 4 : 0 added
# i =  2 # stars in isochrone: 3 20
# newnumstars R and Z:  20 20
#  need to add stars:  0 to 20
# new number of stars in isochrone under new limits 20 : 0 added
# i =  2 # stars in isochrone: 4 18
# newnumstars R and Z:  18 18
#  need to add stars:  0 to 18
# new number of stars in isochrone under new limits 18 : 0 added
# i =  2 # stars in isochrone: 5 8
# newnumstars R and Z:  8 8
#  need to add stars:  0 to 8
# new number of stars in isochrone under new limits 8 : 0 added
# i =  2 # stars in isochrone: 6 33
# newnumstars R and Z:  33 33
#  need to add stars:  0 to 33
# new number of stars in isochrone under new limits 33 : 0 added
# i =  2 # stars in isochrone: 7 42
# newnumstars R and Z:  42 42
#  need to add stars:  0 to 42
# new number of stars in isochrone under new limits 42 : 0 added
# i =  2 # stars in isochrone: 8 644
# newnumstars R and Z:  644 644
#  need to add stars:  0 to 644
# new number of stars in isochrone under new limits 644 : 0 added
# i =  2 # stars in isochrone: 9 57
# newnumstars R and Z:  57 57
#  need to add stars:  0 to 57
# new number of stars in isochrone under new limits 57 : 0 added
# i =  2 # stars in isochrone: 10 17
# newnumstars R and Z:  17 17
#  need to add stars:  0 to 17
# new number of stars in isochrone under new limits 17 : 0 added
# i =  2 # stars in isochrone: 11 459
# newnumstars R and Z:  459 459
#  need to add stars:  0 to 459
# new number of stars in isochrone under new limits 459 : 0 added
# i =  2 # stars in isochrone: 12 567
# newnumstars R and Z:  567 567
#  need to add stars:  0 to 567
# new number of stars in isochrone under new limits 567 : 0 added
# i =  2 # stars in isochrone: 13 303
# newnumstars R and Z:  303 303
#  need to add stars:  0 to 303
# new number of stars in isochrone under new limits 303 : 0 added
# i =  2 # stars in isochrone: 14 57
# newnumstars R and Z:  57 57
#  need to add stars:  0 to 57
# new number of stars in isochrone under new limits 57 : 0 added
# i =  2 # stars in isochrone: 15 1555
# newnumstars R and Z:  1555 1555
#  need to add stars:  0 to 1555
# new number of stars in isochrone under new limits 1555 : 0 added
# i =  3 # stars in isochrone: 0 243
# newnumstars R and Z:  243 243
#  need to add stars:  0 to 243
# new number of stars in isochrone under new limits 243 : 0 added
# i =  3 # stars in isochrone: 1 147
# newnumstars R and Z:  147 147
#  need to add stars:  0 to 147
# new number of stars in isochrone under new limits 147 : 0 added
# i =  3 # stars in isochrone: 2 27
# newnumstars R and Z:  27 27
#  need to add stars:  0 to 27
# new number of stars in isochrone under new limits 27 : 0 added
# i =  3 # stars in isochrone: 3 175
# newnumstars R and Z:  175 175
#  need to add stars:  0 to 175
# new number of stars in isochrone under new limits 175 : 0 added
# i =  3 # stars in isochrone: 4 328
# newnumstars R and Z:  328 328
#  need to add stars:  0 to 328
# new number of stars in isochrone under new limits 328 : 0 added
# i =  3 # stars in isochrone: 5 66
# newnumstars R and Z:  66 66
#  need to add stars:  0 to 66
# new number of stars in isochrone under new limits 66 : 0 added
# i =  3 # stars in isochrone: 6 116
# newnumstars R and Z:  116 116
#  need to add stars:  0 to 116
# new number of stars in isochrone under new limits 116 : 0 added
# i =  3 # stars in isochrone: 7 338
# newnumstars R and Z:  338 338
#  need to add stars:  0 to 338
# new number of stars in isochrone under new limits 338 : 0 added
# i =  3 # stars in isochrone: 8 1776
# newnumstars R and Z:  1776 1776
#  need to add stars:  0 to 1776
# new number of stars in isochrone under new limits 1776 : 0 added
# i =  3 # stars in isochrone: 9 306
# newnumstars R and Z:  306 306
#  need to add stars:  0 to 306
# new number of stars in isochrone under new limits 306 : 0 added
# i =  3 # stars in isochrone: 10 46
# newnumstars R and Z:  46 46
#  need to add stars:  0 to 46
# new number of stars in isochrone under new limits 46 : 0 added
# i =  3 # stars in isochrone: 11 672
# newnumstars R and Z:  672 672
#  need to add stars:  0 to 672
# new number of stars in isochrone under new limits 672 : 0 added
# i =  3 # stars in isochrone: 12 2730
# newnumstars R and Z:  2786 2730
#  need to add stars:  0 to 2730
# new number of stars in isochrone under new limits 2730 : 0 added
# i =  3 # stars in isochrone: 13 885
# newnumstars R and Z:  903 885
#  need to add stars:  0 to 885
# new number of stars in isochrone under new limits 885 : 0 added
# i =  3 # stars in isochrone: 14 584
# newnumstars R and Z:  597 584
#  need to add stars:  0 to 584
# new number of stars in isochrone under new limits 584 : 0 added
# i =  3 # stars in isochrone: 15 7788
# newnumstars R and Z:  7958 7788
#  need to add stars:  0 to 7788
# new number of stars in isochrone under new limits 7788 : 0 added
# i =  4 # stars in isochrone: 0 1463
# newnumstars R and Z:  1475 1463
#  need to add stars:  0 to 1463
# new number of stars in isochrone under new limits 1463 : 0 added
# i =  4 # stars in isochrone: 1 627
# newnumstars R and Z:  632 627
#  need to add stars:  0 to 627
# new number of stars in isochrone under new limits 627 : 0 added
# i =  4 # stars in isochrone: 2 221
# newnumstars R and Z:  223 221
#  need to add stars:  0 to 221
# new number of stars in isochrone under new limits 221 : 0 added
# i =  4 # stars in isochrone: 3 1489
# newnumstars R and Z:  1502 1489
#  need to add stars:  0 to 1489
# new number of stars in isochrone under new limits 1489 : 0 added
# i =  4 # stars in isochrone: 4 1431
# newnumstars R and Z:  1467 1431
#  need to add stars:  0 to 1431
# new number of stars in isochrone under new limits 1431 : 0 added
# i =  4 # stars in isochrone: 5 224
# newnumstars R and Z:  230 224
#  need to add stars:  0 to 224
# new number of stars in isochrone under new limits 224 : 0 added
# i =  4 # stars in isochrone: 6 512
# newnumstars R and Z:  526 512
#  need to add stars:  0 to 512
# new number of stars in isochrone under new limits 512 : 0 added
# i =  4 # stars in isochrone: 7 1600
# newnumstars R and Z:  1644 1600
#  need to add stars:  0 to 1600
# new number of stars in isochrone under new limits 1600 : 0 added
# i =  4 # stars in isochrone: 8 1205
# newnumstars R and Z:  1299 1205
#  need to add stars:  0 to 1205
# new number of stars in isochrone under new limits 1205 : 0 added
# i =  4 # stars in isochrone: 9 1237
# newnumstars R and Z:  1335 1237
#  need to add stars:  0 to 1237
# new number of stars in isochrone under new limits 1237 : 0 added
# i =  4 # stars in isochrone: 10 161
# newnumstars R and Z:  174 161
#  need to add stars:  0 to 161
# new number of stars in isochrone under new limits 161 : 0 added
# i =  4 # stars in isochrone: 11 2121
# newnumstars R and Z:  2296 2121
#  need to add stars:  0 to 2121
# new number of stars in isochrone under new limits 2121 : 0 added
# i =  4 # stars in isochrone: 12 1222
# newnumstars R and Z:  1469 1222
#  need to add stars:  0 to 1222
# new number of stars in isochrone under new limits 1222 : 0 added
# i =  4 # stars in isochrone: 13 931
# newnumstars R and Z:  1123 931
#  need to add stars:  0 to 931
# new number of stars in isochrone under new limits 931 : 0 added
# i =  4 # stars in isochrone: 14 807
# newnumstars R and Z:  976 807
#  need to add stars:  0 to 807
# new number of stars in isochrone under new limits 807 : 0 added
# i =  4 # stars in isochrone: 15 2095
# newnumstars R and Z:  2537 2095
#  need to add stars:  0 to 2095
# new number of stars in isochrone under new limits 2095 : 0 added
# i =  5 # stars in isochrone: 0 915
# newnumstars R and Z:  1142 957
#  need to add stars:  42 to 957
# new number of stars in isochrone under new limits 957 : 42 added
# i =  5 # stars in isochrone: 1 428
# newnumstars R and Z:  535 448
#  need to add stars:  20 to 448
# new number of stars in isochrone under new limits 448 : 20 added
# i =  5 # stars in isochrone: 2 675
# newnumstars R and Z:  848 707
#  need to add stars:  32 to 707
# new number of stars in isochrone under new limits 707 : 32 added
# i =  5 # stars in isochrone: 3 409
# newnumstars R and Z:  516 429
#  need to add stars:  20 to 429
# new number of stars in isochrone under new limits 429 : 20 added
# i =  5 # stars in isochrone: 4 517
# newnumstars R and Z:  690 552
#  need to add stars:  35 to 552
# new number of stars in isochrone under new limits 552 : 35 added
# i =  5 # stars in isochrone: 5 657
# newnumstars R and Z:  884 702
#  need to add stars:  45 to 702
# new number of stars in isochrone under new limits 702 : 45 added
# i =  5 # stars in isochrone: 6 1438
# newnumstars R and Z:  1947 1540
#  need to add stars:  102 to 1540
# new number of stars in isochrone under new limits 1540 : 102 added
# i =  5 # stars in isochrone: 7 666
# newnumstars R and Z:  907 714
#  need to add stars:  48 to 714
# new number of stars in isochrone under new limits 714 : 48 added
# i =  5 # stars in isochrone: 8 1449
# newnumstars R and Z:  2126 1597
#  need to add stars:  148 to 1597
# new number of stars in isochrone under new limits 1597 : 148 added
# i =  5 # stars in isochrone: 9 838
# newnumstars R and Z:  1239 925
#  need to add stars:  87 to 925
# new number of stars in isochrone under new limits 925 : 87 added
# i =  5 # stars in isochrone: 10 409
# newnumstars R and Z:  609 452
#  need to add stars:  43 to 452
# new number of stars in isochrone under new limits 452 : 43 added
# i =  5 # stars in isochrone: 11 1279
# newnumstars R and Z:  1916 1417
#  need to add stars:  138 to 1417
# new number of stars in isochrone under new limits 1417 : 138 added
# i =  5 # stars in isochrone: 12 1575
# newnumstars R and Z:  2886 1809
#  need to add stars:  234 to 1809
# new number of stars in isochrone under new limits 1809 : 234 added
# i =  5 # stars in isochrone: 13 1370
# newnumstars R and Z:  2541 1577
#  need to add stars:  207 to 1577
# new number of stars in isochrone under new limits 1577 : 207 added
# i =  5 # stars in isochrone: 14 1466
# newnumstars R and Z:  2760 1691
#  need to add stars:  225 to 1691
# new number of stars in isochrone under new limits 1691 : 225 added
# i =  5 # stars in isochrone: 15 1551
# newnumstars R and Z:  2949 1790
#  need to add stars:  239 to 1790
# new number of stars in isochrone under new limits 1790 : 239 added
# i =  6 # stars in isochrone: 0 1086
# newnumstars R and Z:  2670 1588
#  need to add stars:  502 to 1588
# new number of stars in isochrone under new limits 1588 : 502 added
# i =  6 # stars in isochrone: 1 594
# newnumstars R and Z:  1483 915
#  need to add stars:  321 to 915
# new number of stars in isochrone under new limits 915 : 321 added
# i =  6 # stars in isochrone: 2 558
# newnumstars R and Z:  1442 871
#  need to add stars:  313 to 871
# new number of stars in isochrone under new limits 871 : 313 added
# i =  6 # stars in isochrone: 3 383
# newnumstars R and Z:  1019 605
#  need to add stars:  222 to 605
# new number of stars in isochrone under new limits 605 : 222 added
# i =  6 # stars in isochrone: 4 233
# newnumstars R and Z:  609 363
#  need to add stars:  130 to 363
# new number of stars in isochrone under new limits 363 : 130 added
# i =  6 # stars in isochrone: 5 263
# newnumstars R and Z:  712 416
#  need to add stars:  153 to 416
# new number of stars in isochrone under new limits 416 : 153 added
# i =  6 # stars in isochrone: 6 417
# newnumstars R and Z:  1170 668
#  need to add stars:  251 to 668
# new number of stars in isochrone under new limits 668 : 251 added
# i =  6 # stars in isochrone: 7 743
# newnumstars R and Z:  2147 1201
#  need to add stars:  458 to 1201
# new number of stars in isochrone under new limits 1201 : 458 added
# i =  6 # stars in isochrone: 8 998
# newnumstars R and Z:  2639 1698
#  need to add stars:  700 to 1698
# new number of stars in isochrone under new limits 1698 : 700 added
# i =  6 # stars in isochrone: 9 1287
# newnumstars R and Z:  3512 2224
#  need to add stars:  937 to 2224
# new number of stars in isochrone under new limits 2224 : 937 added
# i =  6 # stars in isochrone: 10 1861
# newnumstars R and Z:  5227 3271
#  need to add stars:  1410 to 3271
# new number of stars in isochrone under new limits 3271 : 1410 added
# i =  6 # stars in isochrone: 11 2261
# newnumstars R and Z:  6537 4015
#  need to add stars:  1754 to 4015
# new number of stars in isochrone under new limits 4015 : 1754 added
# i =  6 # stars in isochrone: 12 1368
# newnumstars R and Z:  3636 2436
#  need to add stars:  1068 to 2436
# new number of stars in isochrone under new limits 2436 : 1068 added
# i =  6 # stars in isochrone: 13 988
# newnumstars R and Z:  2806 1780
#  need to add stars:  792 to 1780
# new number of stars in isochrone under new limits 1780 : 792 added
# i =  6 # stars in isochrone: 14 1932
# newnumstars R and Z:  5675 3706
#  need to add stars:  1774 to 3706
# new number of stars in isochrone under new limits 3706 : 1774 added
# i =  6 # stars in isochrone: 15 2198
# newnumstars R and Z:  6639 4261
#  need to add stars:  2063 to 4261
# new number of stars in isochrone under new limits 4261 : 2063 added
# i =  7 # stars in isochrone: 0 2211
# newnumstars R and Z:  11733 7629
#  need to add stars:  5418 to 7629
# new number of stars in isochrone under new limits 7629 : 5418 added
# i =  7 # stars in isochrone: 1 488
# newnumstars R and Z:  2713 1725
#  need to add stars:  1237 to 1725
# new number of stars in isochrone under new limits 1725 : 1237 added
# i =  7 # stars in isochrone: 2 260
# newnumstars R and Z:  1565 970
#  need to add stars:  710 to 970
# new number of stars in isochrone under new limits 970 : 710 added
# i =  7 # stars in isochrone: 3 525
# newnumstars R and Z:  3425 2052
#  need to add stars:  1527 to 2052
# new number of stars in isochrone under new limits 2052 : 1527 added
# i =  7 # stars in isochrone: 4 283
# newnumstars R and Z:  1365 973
#  need to add stars:  690 to 973
# new number of stars in isochrone under new limits 973 : 690 added
# i =  7 # stars in isochrone: 5 243
# newnumstars R and Z:  1266 881
#  need to add stars:  638 to 881
# new number of stars in isochrone under new limits 881 : 638 added
# i =  7 # stars in isochrone: 6 347
# newnumstars R and Z:  1949 1324
#  need to add stars:  977 to 1324
# new number of stars in isochrone under new limits 1324 : 977 added
# i =  7 # stars in isochrone: 7 1123
# newnumstars R and Z:  6682 4462
#  need to add stars:  3339 to 4462
# new number of stars in isochrone under new limits 4462 : 3339 added
# i =  7 # stars in isochrone: 8 1129
# newnumstars R and Z:  4836 3653
#  need to add stars:  2524 to 3653
# new number of stars in isochrone under new limits 3653 : 2524 added
# i =  7 # stars in isochrone: 9 945
# newnumstars R and Z:  4299 3207
#  need to add stars:  2262 to 3207
# new number of stars in isochrone under new limits 3207 : 2262 added
# i =  7 # stars in isochrone: 10 998
# newnumstars R and Z:  4817 3554
#  need to add stars:  2556 to 3554
# new number of stars in isochrone under new limits 3554 : 2556 added
# i =  7 # stars in isochrone: 11 984
# newnumstars R and Z:  5508 3642
#  need to add stars:  2658 to 3642
# new number of stars in isochrone under new limits 3642 : 2658 added
# i =  7 # stars in isochrone: 12 875
# newnumstars R and Z:  3469 2736
#  need to add stars:  1861 to 2736
# new number of stars in isochrone under new limits 2736 : 1861 added
# i =  7 # stars in isochrone: 13 1165
# newnumstars R and Z:  4686 3992
#  need to add stars:  2827 to 3992
# new number of stars in isochrone under new limits 3992 : 2827 added
# i =  7 # stars in isochrone: 14 1034
# newnumstars R and Z:  4814 3692
#  need to add stars:  2658 to 3692
# new number of stars in isochrone under new limits 3692 : 2658 added
# i =  7 # stars in isochrone: 15 1070
# newnumstars R and Z:  5276 3952
#  need to add stars:  2882 to 3952
# new number of stars in isochrone under new limits 3952 : 2882 added
# (2601547, 9)
# 2601547 171656

# %%
## Save all new stars and estimate stellar number densities for the old (PANDAS) and new (WFIRST) limits for this field
np.savetxt(path_data+'/WFIfilters_extendedIsochrones_allbands_{}_M31_10_20kpc.txt'.format(WFIRSTlimits[-1]), newstars, header = '# eta, xki, R, Z, Y, J, H, F, FeH')

print ('stellar number density', len(newstars[:,0])*1.0/100, 'stars/kpc^2')
print ('stellar number density', len(newstars[:,0])*1.0/((np.max(locIn[:,0])-np.min(locIn[:,0]))*(np.max(locIn[:,1])-np.min(locIn[:,1]))), 'stars/deg^2')

print (len(oldstars[:,0]), len(newstars[:,0]))

print ('old stellar number density', len(oldstars[:,0])*1.0/100, 'stars/kpc^2')
print ('old stellar number density', len(oldstars[:,0])*1.0/((np.max(locIn[:,0])-np.min(locIn[:,0]))*(np.max(locIn[:,1])-np.min(locIn[:,1]))), 'stars/deg^2')
# Out:
# stellar number density 26015.47 stars/kpc^2
# stellar number density 1184400.6978230262 stars/deg^2
# 171656 2601547
# old stellar number density 1716.56 stars/kpc^2
# old stellar number density 78149.45729810355 stars/deg^2

# %%
#asdfghj

# %% [markdown]
# Do WFIRST for M31 field 30-40 kpc

# %%
## Repeat as above for the field farther out in the M31 halo

locIn = np.loadtxt(path_data+'/WFIfilters_FromPANDAS_g0limit25.5_ZRcorrection_RAdec_M31_30_40kpc_new.vot.txt', skiprows = 1, usecols = [4,5])
magsIn = np.loadtxt(path_data+'/WFIfilters_FromPANDAS_g0limit25.5_ZRcorrection_RAdec_M31_30_40kpc_new.vot.txt', skiprows = 1, usecols = [0,1])
fehIn = np.loadtxt(path_data+'/WFIfilters_FromPANDAS_g0limit25.5_ZRcorrection_RAdec_M31_30_40kpc_new.vot.txt', skiprows = 1, usecols = [6])

isos = np.loadtxt(path_data+'/WFIRST_PARSEC_isochrones_grid.txt')
dist_mod_And = 24.47 #from Ibata+2014

all_iso = []
start_feh = [0,0,0,0]
start_age = np.repeat(0,16)
j_feh = 1
j_age = 1
for i in range(len(isos[:,0])-1):
    if (isos[i+1,0] != isos[i,0]):
        start_feh[j_feh] = i+1
        j_feh = j_feh + 1
    if (isos[i+1,1] != isos[i,1]):
        start_age[j_age] = i+1
        j_age = j_age + 1

fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize = [18,6])
ax1.hist2d((magsIn[:,0]-magsIn[:,1]), magsIn[:,0], bins = 100, range = [[-1,4],[17,25]])
for j in range(15):
    ax1.scatter((isos[start_age[j]:start_age[j+1],10]-isos[start_age[j]:start_age[j+1],11]), 
            isos[start_age[j]:start_age[j+1],10] + dist_mod_And, s = 2)
ax1.scatter((isos[start_age[j+1]:,10]-isos[start_age[j+1]:,11]), 
            isos[start_age[j+1]:,10] + dist_mod_And, s = 2)
ax1.set_xlabel('R - Z')
ax1.set_ylabel('R')
ax1.axis([-1,4,25,17])
ax2.hist2d((magsIn[:,0]-magsIn[:,1]), magsIn[:,1], bins = 100, range = [[-1,4],[17,25]])
for j in range(15):
    ax2.scatter((isos[start_age[j]:start_age[j+1],10]-isos[start_age[j]:start_age[j+1],11]), 
            isos[start_age[j]:start_age[j+1],11] + dist_mod_And, s = 2)
ax2.scatter((isos[start_age[j+1]:,10]-isos[start_age[j+1]:,11]), 
            isos[start_age[j+1]:,11] + dist_mod_And, s = 2)
for j in range(15):
    ax2.scatter((isos[start_age[j]:start_age[j+1],10]-isos[start_age[j]:start_age[j+1],11]), 
            isos[start_age[j]:start_age[j+1],11] + 12, s = 2)
ax2.scatter((isos[start_age[j+1]:,10]-isos[start_age[j+1]:,11]), 
            isos[start_age[j+1]:,11] + 12, s = 2)
for j in range(15):
    ax2.scatter((isos[start_age[j]:start_age[j+1],10]-isos[start_age[j]:start_age[j+1],11]), 
            isos[start_age[j]:start_age[j+1],11] + 7, s = 2)
ax2.scatter((isos[start_age[j+1]:,10]-isos[start_age[j+1]:,11]), 
            isos[start_age[j+1]:,11] + 7, s = 2)
ax2.set_xlabel('R - Z')
ax2.set_ylabel('Z')
ax2.axis([-1,4,25,17])
ax3.hist2d(magsIn[:,0], magsIn[:,1], bins = 50, range = [[17,25],[17,25]])
for j in range(15):
    ax3.scatter(isos[start_age[j]:start_age[j+1],10] + dist_mod_And, isos[start_age[j]:start_age[j+1],11] + dist_mod_And, s = 2)
ax3.scatter(isos[start_age[j+1]:,10] + dist_mod_And, isos[start_age[j+1]:,11]  + dist_mod_And, s = 2)
ax3.set_xlabel('R')
ax3.set_ylabel('Z')
ax3.axis([25,17,25,17])
# Out:
# (25.0, 17.0, 25.0, 17.0)

# %%
match = np.zeros(len(magsIn[:,0]))
matchFeH = np.zeros(len(magsIn[:,0]))
matchAge = np.zeros(len(magsIn[:,0]))
matchgal = np.zeros(len(magsIn[:,0]))
print (len(match), len(isos[:,13]))
range1 = np.max(np.concatenate((magsIn[:,1], isos[:,11] + dist_mod_And,
                                isos[:,11] + 8, isos[:,11] + 10, isos[:,11] + 12, isos[:,11] + 14,
                                isos[:,11] + 16, isos[:,11] + 18, isos[:,11] + 20), axis=0))
- np.min(np.concatenate((magsIn[:,1], isos[:,11] + dist_mod_And,
                         isos[:,11] + 8, isos[:,11] + 10, isos[:,11] + 12, isos[:,11] + 14,
                         isos[:,11] + 16, isos[:,11] + 18, isos[:,11] + 20), axis=0))
range2 = np.max(np.concatenate((magsIn[:,0]-magsIn[:,1], isos[:,10]-isos[:,11], isos[:,10]-isos[:,11], 
                                isos[:,10]-isos[:,11], isos[:,10]-isos[:,11], isos[:,10]-isos[:,11], 
                                isos[:,10]-isos[:,11], isos[:,10]-isos[:,11], isos[:,10]-isos[:,11]), axis=0))
- np.min(np.concatenate((magsIn[:,0]-magsIn[:,1], isos[:,10]-isos[:,11], isos[:,10]-isos[:,11], 
                         isos[:,10]-isos[:,11], isos[:,10]-isos[:,11], isos[:,10]-isos[:,11],
                         isos[:,10]-isos[:,11], isos[:,10]-isos[:,11], isos[:,10]-isos[:,11]), axis=0))
for i in range(len(magsIn[:,0])):
    rescale_dist1 = (magsIn[i,1] - np.concatenate((isos[:,11] + dist_mod_And,
                                isos[:,11] + 8, isos[:,11] + 10, isos[:,11] + 12, isos[:,11] + 14,
                                isos[:,11] + 16, isos[:,11] + 18, isos[:,11] + 20), axis=0)) / range1
    rescale_dist2 = ((magsIn[i,0]-magsIn[i,1]) - np.concatenate((isos[:,10]-isos[:,11], isos[:,10]-isos[:,11], 
                                isos[:,10]-isos[:,11], isos[:,10]-isos[:,11], isos[:,10]-isos[:,11], 
                                isos[:,10]-isos[:,11], isos[:,10]-isos[:,11], isos[:,10]-isos[:,11]), axis=0)) / range2
    match[i] = np.argmin(np.sqrt(rescale_dist1**2 + rescale_dist2**2))
    if np.logical_and(match[i] < start_age[1], match[i] >= start_age[0]):
        matchFeH[i] = isos[np.asarray(start_feh),0][0]
        matchAge[i] = isos[np.asarray(start_age),1][0]
        matchgal[i] = 0
    elif np.logical_and(match[i] < start_age[2], match[i] >= start_age[1]):
        matchFeH[i] = isos[np.asarray(start_feh),0][0]
        matchAge[i] = isos[np.asarray(start_age),1][1]
        matchgal[i] = 0
    elif np.logical_and(match[i] < start_age[3], match[i] >= start_age[2]):
        matchFeH[i] = isos[np.asarray(start_feh),0][0]
        matchAge[i] = isos[np.asarray(start_age),1][2]
        matchgal[i] = 0
    elif np.logical_and(match[i] < start_age[4], match[i] >= start_age[3]):
        matchFeH[i] = isos[np.asarray(start_feh),0][0]
        matchAge[i] = isos[np.asarray(start_age),1][3]
        matchgal[i] = 0
    elif np.logical_and(match[i] < start_age[5], match[i] >= start_age[4]):
        matchFeH[i] = isos[np.asarray(start_feh),0][1]
        matchAge[i] = isos[np.asarray(start_age),1][0]
        matchgal[i] = 0
    elif np.logical_and(match[i] < start_age[6], match[i] >= start_age[5]):
        matchFeH[i] = isos[np.asarray(start_feh),0][1]
        matchAge[i] = isos[np.asarray(start_age),1][1]
        matchgal[i] = 0
    elif np.logical_and(match[i] < start_age[7], match[i] >= start_age[6]):
        matchFeH[i] = isos[np.asarray(start_feh),0][1]
        matchAge[i] = isos[np.asarray(start_age),1][2]
        matchgal[i] = 0
    elif np.logical_and(match[i] < start_age[8], match[i] >= start_age[7]):
        matchFeH[i] = isos[np.asarray(start_feh),0][1]
        matchAge[i] = isos[np.asarray(start_age),1][3]
        matchgal[i] = 0
    elif np.logical_and(match[i] < start_age[9], match[i] >= start_age[8]):
        matchFeH[i] = isos[np.asarray(start_feh),0][2]
        matchAge[i] = isos[np.asarray(start_age),1][0]
        matchgal[i] = 0
    elif np.logical_and(match[i] < start_age[10], match[i] >= start_age[9]):
        matchFeH[i] = isos[np.asarray(start_feh),0][2]
        matchAge[i] = isos[np.asarray(start_age),1][1]
        matchgal[i] = 0
    elif np.logical_and(match[i] < start_age[11], match[i] >= start_age[10]):
        matchFeH[i] = isos[np.asarray(start_feh),0][2]
        matchAge[i] = isos[np.asarray(start_age),1][2]
        matchgal[i] = 0
    elif np.logical_and(match[i] < start_age[12], match[i] >= start_age[11]):
        matchFeH[i] = isos[np.asarray(start_feh),0][2]
        matchAge[i] = isos[np.asarray(start_age),1][3]
        matchgal[i] = 0
    elif np.logical_and(match[i] < start_age[13], match[i] >= start_age[12]):
        matchFeH[i] = isos[np.asarray(start_feh),0][3]
        matchAge[i] = isos[np.asarray(start_age),1][0]
        matchgal[i] = 0
    elif np.logical_and(match[i] < start_age[14], match[i] >= start_age[13]):
        matchFeH[i] = isos[np.asarray(start_feh),0][3]
        matchAge[i] = isos[np.asarray(start_age),1][1]
        matchgal[i] = 0
    elif np.logical_and(match[i] < start_age[15], match[i] >= start_age[14]):
        matchFeH[i] = isos[np.asarray(start_feh),0][3]
        matchAge[i] = isos[np.asarray(start_age),1][2]
        matchgal[i] = 0
    elif np.logical_and(match[i] < len(isos[:,13]), match[i] >= start_age[15]):
        matchFeH[i] = isos[np.asarray(start_feh),0][3]
        matchAge[i] = isos[np.asarray(start_age),1][3]
        matchgal[i] = 0
    elif match[i] > len(isos[:,13]) + start_age[0]:
        MWmatch = match[i] % len(isos[:,13])
        if np.logical_and(MWmatch < start_age[1], MWmatch > start_age[0]):
            matchFeH[i] = isos[np.asarray(start_feh),0][0]
            matchAge[i] = isos[np.asarray(start_age),1][0]
            matchgal[i] = np.round(match[i] / len(isos[:,13])).astype('int')
        elif np.logical_and(MWmatch < start_age[2], MWmatch > start_age[1]):
            matchFeH[i] = isos[np.asarray(start_feh),0][0]
            matchAge[i] = isos[np.asarray(start_age),1][1]
            matchgal[i] = np.round(match[i] / len(isos[:,13])).astype('int')
        elif np.logical_and(MWmatch < start_age[3], MWmatch > start_age[2]):
            matchFeH[i] = isos[np.asarray(start_feh),0][0]
            matchAge[i] = isos[np.asarray(start_age),1][2]
            matchgal[i] = np.round(match[i] / len(isos[:,13])).astype('int')
        elif np.logical_and(MWmatch < start_age[4], MWmatch > start_age[3]):
            matchFeH[i] = isos[np.asarray(start_feh),0][0]
            matchAge[i] = isos[np.asarray(start_age),1][3]
            matchgal[i] = np.round(match[i] / len(isos[:,13])).astype('int')
        elif np.logical_and(MWmatch < start_age[5], MWmatch > start_age[4]):
            matchFeH[i] = isos[np.asarray(start_feh),0][1]
            matchAge[i] = isos[np.asarray(start_age),1][0]
            matchgal[i] = np.round(match[i] / len(isos[:,13])).astype('int')
        elif np.logical_and(MWmatch < start_age[6], MWmatch > start_age[5]):
            matchFeH[i] = isos[np.asarray(start_feh),0][1]
            matchAge[i] = isos[np.asarray(start_age),1][1]
            matchgal[i] = np.round(match[i] / len(isos[:,13])).astype('int')
        elif np.logical_and(MWmatch < start_age[7], MWmatch > start_age[6]):
            matchFeH[i] = isos[np.asarray(start_feh),0][1]
            matchAge[i] = isos[np.asarray(start_age),1][2]
            matchgal[i] = np.round(match[i] / len(isos[:,13])).astype('int')
        elif np.logical_and(MWmatch < start_age[8], MWmatch > start_age[7]):
            matchFeH[i] = isos[np.asarray(start_feh),0][1]
            matchAge[i] = isos[np.asarray(start_age),1][3]
            matchgal[i] = np.round(match[i] / len(isos[:,13])).astype('int')
        elif np.logical_and(MWmatch < start_age[9], MWmatch > start_age[8]):
            matchFeH[i] = isos[np.asarray(start_feh),0][2]
            matchAge[i] = isos[np.asarray(start_age),1][0]
            matchgal[i] = np.round(match[i] / len(isos[:,13])).astype('int')
        elif np.logical_and(MWmatch < start_age[10], MWmatch > start_age[9]):
            matchFeH[i] = isos[np.asarray(start_feh),0][2]
            matchAge[i] = isos[np.asarray(start_age),1][1]
            matchgal[i] = np.round(match[i] / len(isos[:,13])).astype('int')
        elif np.logical_and(MWmatch < start_age[11], MWmatch > start_age[10]):
            matchFeH[i] = isos[np.asarray(start_feh),0][2]
            matchAge[i] = isos[np.asarray(start_age),1][2]
            matchgal[i] = np.round(match[i] / len(isos[:,13])).astype('int')
        elif np.logical_and(MWmatch < start_age[12], MWmatch > start_age[11]):
            matchFeH[i] = isos[np.asarray(start_feh),0][2]
            matchAge[i] = isos[np.asarray(start_age),1][3]
            matchgal[i] = np.round(match[i] / len(isos[:,13])).astype('int')
        elif np.logical_and(MWmatch < start_age[13], MWmatch > start_age[12]):
            matchFeH[i] = isos[np.asarray(start_feh),0][3]
            matchAge[i] = isos[np.asarray(start_age),1][0]
            matchgal[i] = np.round(match[i] / len(isos[:,13])).astype('int')
        elif np.logical_and(MWmatch < start_age[14], MWmatch > start_age[13]):
            matchFeH[i] = isos[np.asarray(start_feh),0][3]
            matchAge[i] = isos[np.asarray(start_age),1][1]
            matchgal[i] = np.round(match[i] / len(isos[:,13])).astype('int')
        elif np.logical_and(MWmatch < start_age[15], MWmatch > start_age[14]):
            matchFeH[i] = isos[np.asarray(start_feh),0][3]
            matchAge[i] = isos[np.asarray(start_age),1][2]
            matchgal[i] = np.round(match[i] / len(isos[:,13])).astype('int')
        elif np.logical_and(MWmatch < len(isos[:,13]), match[i] >= len(isos[:,13]) + start_age[15]):
            matchFeH[i] = isos[np.asarray(start_feh),0][3]
            matchAge[i] = isos[np.asarray(start_age),1][3]
            matchgal[i] = np.round(match[i] / len(isos[:,13])).astype('int')

        
print ("number of stars matched to FeH of isochrones:")
print (isos[np.asarray(start_feh),0][0], np.sum(matchFeH == isos[np.asarray(start_feh),0][0]))
print (isos[np.asarray(start_feh),0][1], np.sum(matchFeH == isos[np.asarray(start_feh),0][1]))
print (isos[np.asarray(start_feh),0][2], np.sum(matchFeH == isos[np.asarray(start_feh),0][2]))
print (isos[np.asarray(start_feh),0][3], np.sum(matchFeH == isos[np.asarray(start_feh),0][3]))
print ("number of stars matched to Age of isochrones:")
print (10.0**isos[np.asarray(start_age),1][0]/1e9, np.sum(matchAge == isos[np.asarray(start_age),1][0]))
print (10.0**isos[np.asarray(start_age),1][1]/1e9, np.sum(matchAge == isos[np.asarray(start_age),1][1]))
print (10.0**isos[np.asarray(start_age),1][2]/1e9, np.sum(matchAge == isos[np.asarray(start_age),1][2]))
print (10.0**isos[np.asarray(start_age),1][3]/1e9, np.sum(matchAge == isos[np.asarray(start_age),1][3]))

print ("galaxy")
print ("MW", np.sum(matchgal >= 1))
print ("M31", np.sum(matchgal == 0))
# Out:
# 63171 3886
# number of stars matched to FeH of isochrones:
# 4.916e-05 14079
# 0.00049127 5487
# 0.0048287 14220
# 0.041517 28425
# number of stars matched to Age of isochrones:
# 8.491804750363144 18160
# 9.506047936562808 10954
# 10.49542428652324 9895
# 11.508003889444357 23202
# galaxy
# MW 41857
# M31 21314

# %%
fig, axes = plt.subplots(4,4, figsize = [20,20])
for j in range(16):
    axes[j%4,int(j/4)].hist2d((magsIn[np.logical_and(matchFeH == isos[np.asarray(start_feh),0][int(j/4)], 
                                      matchAge == isos[np.asarray(start_age),1][j%4]),0]
                -magsIn[np.logical_and(matchFeH == isos[np.asarray(start_feh),0][int(j/4)], 
                                      matchAge == isos[np.asarray(start_age),1][j%4]),1]), 
               magsIn[np.logical_and(matchFeH == isos[np.asarray(start_feh),0][int(j/4)], 
                                      matchAge == isos[np.asarray(start_age),1][j%4]),1], 
               bins = 50, range = [[-1,4],[17,25]])
    if j == 15:
        axes[j%4,int(j/4)].scatter((isos[start_age[j]:,10]-isos[start_age[j]:,11]), 
            isos[start_age[j]:,11]  + dist_mod_And, s = 2)
        axes[j%4,int(j/4)].scatter((isos[start_age[j]:,10]-isos[start_age[j]:,11]), 
            isos[start_age[j]:,11]  + 8, s = 2)
        axes[j%4,int(j/4)].scatter((isos[start_age[j]:,10]-isos[start_age[j]:,11]), 
            isos[start_age[j]:,11]  + 10, s = 2)
        axes[j%4,int(j/4)].scatter((isos[start_age[j]:,10]-isos[start_age[j]:,11]), 
            isos[start_age[j]:,11]  + 12, s = 2)
        axes[j%4,int(j/4)].scatter((isos[start_age[j]:,10]-isos[start_age[j]:,11]), 
            isos[start_age[j]:,11]  + 14, s = 2)        
        axes[j%4,int(j/4)].scatter((isos[start_age[j]:,10]-isos[start_age[j]:,11]), 
            isos[start_age[j]:,11]  + 16, s = 2)        
        axes[j%4,int(j/4)].scatter((isos[start_age[j]:,10]-isos[start_age[j]:,11]), 
            isos[start_age[j]:,11]  + 18, s = 2)       
        axes[j%4,int(j/4)].scatter((isos[start_age[j]:,10]-isos[start_age[j]:,11]), 
            isos[start_age[j]:,11]  + 20, s = 2)       
    else:
        axes[j%4,int(j/4)].scatter((isos[start_age[j]:start_age[j+1],10]-isos[start_age[j]:start_age[j+1],11]), 
            isos[start_age[j]:start_age[j+1],11] + dist_mod_And, s = 2)
        axes[j%4,int(j/4)].scatter((isos[start_age[j]:start_age[j+1],10]-isos[start_age[j]:start_age[j+1],11]), 
            isos[start_age[j]:start_age[j+1],11] + 8, s = 2)
        axes[j%4,int(j/4)].scatter((isos[start_age[j]:start_age[j+1],10]-isos[start_age[j]:start_age[j+1],11]), 
            isos[start_age[j]:start_age[j+1],11] + 10, s = 2)
        axes[j%4,int(j/4)].scatter((isos[start_age[j]:start_age[j+1],10]-isos[start_age[j]:start_age[j+1],11]), 
            isos[start_age[j]:start_age[j+1],11] + 12, s = 2)
        axes[j%4,int(j/4)].scatter((isos[start_age[j]:start_age[j+1],10]-isos[start_age[j]:start_age[j+1],11]), 
            isos[start_age[j]:start_age[j+1],11] + 14, s = 2)
        axes[j%4,int(j/4)].scatter((isos[start_age[j]:start_age[j+1],10]-isos[start_age[j]:start_age[j+1],11]), 
            isos[start_age[j]:start_age[j+1],11] + 16, s = 2)
        axes[j%4,int(j/4)].scatter((isos[start_age[j]:start_age[j+1],10]-isos[start_age[j]:start_age[j+1],11]), 
            isos[start_age[j]:start_age[j+1],11] + 18, s = 2)
        axes[j%4,int(j/4)].scatter((isos[start_age[j]:start_age[j+1],10]-isos[start_age[j]:start_age[j+1],11]), 
            isos[start_age[j]:start_age[j+1],11] + 20, s = 2)
    axes[j%4,int(j/4)].text(2,23.5,'[Fe/H] = %0.1e' %(isos[np.asarray(start_feh),0][int(j/4)]), color = 'white')
    axes[j%4,int(j/4)].text(2,24,'age = %0.1f Gyr' %(10.0**isos[np.asarray(start_age),1][j%4]/1e9), color = 'white')
    axes[j%4,int(j/4)].text(2,24.5,'# stars = %d' %(np.sum(np.logical_and(matchFeH == isos[np.asarray(start_feh),0][int(j/4)], 
                                      matchAge == isos[np.asarray(start_age),1][j%4]))), color = 'white')
    axes[j%4,int(j/4)].text(2,25,'# stars And = %d' %(np.sum(np.logical_and(np.logical_and(matchFeH == isos[np.asarray(start_feh),0][int(j/4)], 
                                      matchAge == isos[np.asarray(start_age),1][j%4]), matchgal == 0))), color = 'white')
    axes[j%4,int(j/4)].set_xlabel('R - Z')
    axes[j%4,int(j/4)].set_ylabel('Z')
    axes[j%4,int(j/4)].axis([-1,4,25,17])
def kde(x, x_num, x_grid, bandwidth=0.2, **kwargs):
    """Kernel Density Estimation with Scipy"""
    x_tot = np.asarray([])
    for i in range(len(x)):
        x_tot = np.concatenate((x_tot, np.repeat(x[i], int(x_num[i]))), axis = 0)
    kde = gaussian_kde(x_tot)
    return kde.evaluate(x_grid)


def generate_rand_from_pdf(pdf, x_grid, num):
    cdf = np.cumsum(pdf)
    cdf = cdf / cdf[-1]
    values = np.random.rand(num)
    value_bins = np.searchsorted(cdf, values)
    random_from_cdf = x_grid[value_bins]
    return random_from_cdf
    
wfirst_mags = np.loadtxt(path_data+'/WFIRST_PARSEC_isochrones_grid.txt', skiprows = 12, usecols = [10,11,12,13,14,15])
oldstars = np.concatenate((locIn, np.reshape(magsIn, (len(magsIn),2)), np.reshape(fehIn, (len(fehIn),1))), axis=1)
newstars = np.asarray([])
#for i in range(1):
for i in range(8): #MW inner halo, MW outer halo, M31
    if i == 0: dist_mod = dist_mod_And
    elif i >= 1: dist_mod = 6 + 2*i
    for j in range(16):
    #for j in range(1):
        start_isochrone = start_age[j]
        if j == len(start_age)-1:
            end_isochrone = len(wfirst_mags[:,0])-1
        else:
            end_isochrone = start_age[j+1]-1
        inter_Rmags = interp.interp1d(wfirst_mags[start_isochrone:end_isochrone,1], 
                        wfirst_mags[start_isochrone:end_isochrone,0], assume_sorted = False, fill_value = "extrapolate")
        inter_Ymags = interp.interp1d(wfirst_mags[start_isochrone:end_isochrone,1], 
                        wfirst_mags[start_isochrone:end_isochrone,2], assume_sorted = False, fill_value = "extrapolate")
        inter_Jmags = interp.interp1d(wfirst_mags[start_isochrone:end_isochrone,1], 
                        wfirst_mags[start_isochrone:end_isochrone,3], assume_sorted = False, fill_value = "extrapolate")
        inter_Hmags = interp.interp1d(wfirst_mags[start_isochrone:end_isochrone,1], 
                        wfirst_mags[start_isochrone:end_isochrone,4], assume_sorted = False, fill_value = "extrapolate")
        inter_Fmags = interp.interp1d(wfirst_mags[start_isochrone:end_isochrone,1], 
                        wfirst_mags[start_isochrone:end_isochrone,5], assume_sorted = False, fill_value = "extrapolate")
        lumfunc = np.loadtxt(path_data+'/WFIRST_PARSEC_lumfunc_isochrone%d_allbands.txt' %j)
        
        numstars = np.sum(np.logical_and(np.logical_and(matchFeH == isos[np.asarray(start_feh),0][int(j/4)],
                                      matchAge == isos[np.asarray(start_age),1][j%4]), matchgal == i))
        print ('i = ', i, '# stars in isochrone:', j, numstars)
        feh = isos[np.asarray(start_feh),0][int(j/4)]
        limits = [np.max(magsIn[:,0]), np.max(magsIn[:,1])]
        if numstars > 0:
            numunderlim = np.asarray([np.sum(lumfunc[lumfunc[:,0] + dist_mod < limits[0],1]), 
                np.sum(lumfunc[lumfunc[:,2] + dist_mod < limits[1],3])])
            #print 'number of 1e5 stars luminosity function under old limits of', limits, ':', numunderlim
            newnumunderlim = np.asarray([np.sum(lumfunc[lumfunc[:,0] + dist_mod < WFIRSTlimits[0],1]), 
                np.sum(lumfunc[lumfunc[:,2] + dist_mod < WFIRSTlimits[1],3])])
            #print 'number of 1e5 stars luminosity function under new limits of', WFIRSTlimits, ':',  newnumunderlim
            newnumstars = np.round(numstars*newnumunderlim[1]*1.0/numunderlim[1]).astype('int')
            addstars = newnumstars - numstars
            print (" need to add stars: ", addstars, "to", newnumstars)
            x_grid_Z = np.linspace(np.min(wfirst_mags[start_isochrone:end_isochrone,1] + dist_mod), 
                                   np.min([WFIRSTlimits[1], np.max(wfirst_mags[start_isochrone:end_isochrone,1]) + dist_mod]), 
                                   newnumstars)
            kdepdf_Z = kde(lumfunc[lumfunc[:,2] + dist_mod < WFIRSTlimits[1],2] + dist_mod,
                       lumfunc[lumfunc[:,2] + dist_mod < WFIRSTlimits[1],3], x_grid_Z)
            random_Z = generate_rand_from_pdf(kdepdf_Z, x_grid_Z, newnumstars)
            random_R = inter_Rmags(random_Z - dist_mod) + dist_mod
            random_H = inter_Hmags(random_Z - dist_mod) + dist_mod
            random_Y = inter_Ymags(random_Z - dist_mod) + dist_mod
            random_J = inter_Jmags(random_Z - dist_mod) + dist_mod
            random_F = inter_Fmags(random_Z - dist_mod) + dist_mod
            random_xki = np.random.uniform(low = np.min(locIn[:,0]), high = np.max(locIn[:,0]), size = newnumstars)
            random_eta = np.random.uniform(low = np.min(locIn[:,1]), high = np.max(locIn[:,1]), size = newnumstars)
            if newstars.size == 0:
                newstars = np.concatenate((np.reshape(random_xki, (len(random_xki),1)), 
                                        np.reshape(random_eta, (len(random_eta),1)), 
                                        np.reshape(random_R, (len(random_R),1)), 
                                        np.reshape(random_Z, (len(random_Z),1)), 
                                        np.reshape(random_Y, (len(random_Y),1)), 
                                        np.reshape(random_J, (len(random_J),1)),
                                        np.reshape(random_H, (len(random_H),1)), 
                                        np.reshape(random_F, (len(random_F),1)),
                                        np.reshape(np.repeat(np.log10(feh*1.0/0.0152), len(random_xki))
                                                , (len(random_xki),1))), axis = 1)
            else:
                newstars = np.concatenate((newstars, np.concatenate((np.reshape(random_xki, (len(random_xki),1)), 
                                        np.reshape(random_eta, (len(random_eta),1)), 
                                        np.reshape(random_R, (len(random_R),1)), 
                                        np.reshape(random_Z, (len(random_Z),1)), 
                                        np.reshape(random_Y, (len(random_Y),1)), 
                                        np.reshape(random_J, (len(random_J),1)),
                                        np.reshape(random_H, (len(random_H),1)), 
                                        np.reshape(random_F, (len(random_F),1)),
                                        np.reshape(np.repeat(np.log10(feh*1.0/0.0152), len(random_xki))
                                                , (len(random_xki),1))), axis = 1)), axis = 0)
            print ('new number of stars in isochrone under new limits', newnumstars, ':', addstars, "added")

print (np.shape(newstars))
print (len(newstars[:,0]), len(oldstars[:,0]))
# Out:
# i =  0 # stars in isochrone: 0 1465
#  need to add stars:  56032 to 57497
# new number of stars in isochrone under new limits 57497 : 56032 added
# i =  0 # stars in isochrone: 1 1197
#  need to add stars:  49731 to 50928
# new number of stars in isochrone under new limits 50928 : 49731 added
# i =  0 # stars in isochrone: 2 1672
#  need to add stars:  70756 to 72428
# new number of stars in isochrone under new limits 72428 : 70756 added
# i =  0 # stars in isochrone: 3 3630
#  need to add stars:  153346 to 156976
# new number of stars in isochrone under new limits 156976 : 153346 added
# i =  0 # stars in isochrone: 4 480
#  need to add stars:  20438 to 20918
# new number of stars in isochrone under new limits 20918 : 20438 added
# i =  0 # stars in isochrone: 5 329
#  need to add stars:  14267 to 14596
# new number of stars in isochrone under new limits 14596 : 14267 added
# i =  0 # stars in isochrone: 6 356
#  need to add stars:  15454 to 15810
# new number of stars in isochrone under new limits 15810 : 15454 added
# i =  0 # stars in isochrone: 7 565
#  need to add stars:  24981 to 25546
# new number of stars in isochrone under new limits 25546 : 24981 added
# i =  0 # stars in isochrone: 8 1333
#  need to add stars:  52931 to 54264
# new number of stars in isochrone under new limits 54264 : 52931 added
# i =  0 # stars in isochrone: 9 863
#  need to add stars:  35366 to 36229
# new number of stars in isochrone under new limits 36229 : 35366 added
# i =  0 # stars in isochrone: 10 1077
#  need to add stars:  46521 to 47598
# new number of stars in isochrone under new limits 47598 : 46521 added
# i =  0 # stars in isochrone: 11 3130
#  need to add stars:  134896 to 138026
# new number of stars in isochrone under new limits 138026 : 134896 added
# i =  0 # stars in isochrone: 12 2052
#  need to add stars:  83865 to 85917
# new number of stars in isochrone under new limits 85917 : 83865 added
# i =  0 # stars in isochrone: 13 1320
#  need to add stars:  56896 to 58216
# new number of stars in isochrone under new limits 58216 : 56896 added
# i =  0 # stars in isochrone: 14 550
#  need to add stars:  24238 to 24788
# new number of stars in isochrone under new limits 24788 : 24238 added
# i =  0 # stars in isochrone: 15 335
#  need to add stars:  14021 to 14356
# new number of stars in isochrone under new limits 14356 : 14021 added
# i =  1 # stars in isochrone: 0 14
#  need to add stars:  0 to 14
# new number of stars in isochrone under new limits 14 : 0 added
# i =  1 # stars in isochrone: 1 10
#  need to add stars:  0 to 10
# new number of stars in isochrone under new limits 10 : 0 added
# i =  1 # stars in isochrone: 2 9
#  need to add stars:  0 to 9
# new number of stars in isochrone under new limits 9 : 0 added
# i =  1 # stars in isochrone: 3 11
#  need to add stars:  0 to 11
# new number of stars in isochrone under new limits 11 : 0 added
# i =  1 # stars in isochrone: 4 12
#  need to add stars:  0 to 12
# new number of stars in isochrone under new limits 12 : 0 added
# i =  1 # stars in isochrone: 5 0
# i =  1 # stars in isochrone: 6 5
#  need to add stars:  0 to 5
# new number of stars in isochrone under new limits 5 : 0 added
# i =  1 # stars in isochrone: 7 9
#  need to add stars:  0 to 9
# new number of stars in isochrone under new limits 9 : 0 added
# i =  1 # stars in isochrone: 8 209
#  need to add stars:  0 to 209
# new number of stars in isochrone under new limits 209 : 0 added
# i =  1 # stars in isochrone: 9 0
# i =  1 # stars in isochrone: 10 0
# i =  1 # stars in isochrone: 11 0
# i =  1 # stars in isochrone: 12 0
# i =  1 # stars in isochrone: 13 0
# i =  1 # stars in isochrone: 14 0
# i =  1 # stars in isochrone: 15 0
# i =  2 # stars in isochrone: 0 44
#  need to add stars:  0 to 44
# new number of stars in isochrone under new limits 44 : 0 added
# i =  2 # stars in isochrone: 1 25
#  need to add stars:  0 to 25
# new number of stars in isochrone under new limits 25 : 0 added
# i =  2 # stars in isochrone: 2 12
#  need to add stars:  0 to 12
# new number of stars in isochrone under new limits 12 : 0 added
# i =  2 # stars in isochrone: 3 36
#  need to add stars:  0 to 36
# new number of stars in isochrone under new limits 36 : 0 added
# i =  2 # stars in isochrone: 4 29
#  need to add stars:  0 to 29
# new number of stars in isochrone under new limits 29 : 0 added
# i =  2 # stars in isochrone: 5 16
#  need to add stars:  0 to 16
# new number of stars in isochrone under new limits 16 : 0 added
# i =  2 # stars in isochrone: 6 34
#  need to add stars:  0 to 34
# new number of stars in isochrone under new limits 34 : 0 added
# i =  2 # stars in isochrone: 7 34
#  need to add stars:  0 to 34
# new number of stars in isochrone under new limits 34 : 0 added
# i =  2 # stars in isochrone: 8 409
#  need to add stars:  0 to 409
# new number of stars in isochrone under new limits 409 : 0 added
# i =  2 # stars in isochrone: 9 59
#  need to add stars:  0 to 59
# new number of stars in isochrone under new limits 59 : 0 added
# i =  2 # stars in isochrone: 10 12
#  need to add stars:  0 to 12
# new number of stars in isochrone under new limits 12 : 0 added
# i =  2 # stars in isochrone: 11 417
#  need to add stars:  0 to 417
# new number of stars in isochrone under new limits 417 : 0 added
# i =  2 # stars in isochrone: 12 490
#  need to add stars:  0 to 490
# new number of stars in isochrone under new limits 490 : 0 added
# i =  2 # stars in isochrone: 13 263
#  need to add stars:  0 to 263
# new number of stars in isochrone under new limits 263 : 0 added
# i =  2 # stars in isochrone: 14 66
#  need to add stars:  0 to 66
# new number of stars in isochrone under new limits 66 : 0 added
# i =  2 # stars in isochrone: 15 937
#  need to add stars:  0 to 937
# new number of stars in isochrone under new limits 937 : 0 added
# i =  3 # stars in isochrone: 0 84
#  need to add stars:  0 to 84
# new number of stars in isochrone under new limits 84 : 0 added
# i =  3 # stars in isochrone: 1 65
#  need to add stars:  0 to 65
# new number of stars in isochrone under new limits 65 : 0 added
# i =  3 # stars in isochrone: 2 39
#  need to add stars:  0 to 39
# new number of stars in isochrone under new limits 39 : 0 added
# i =  3 # stars in isochrone: 3 56
#  need to add stars:  0 to 56
# new number of stars in isochrone under new limits 56 : 0 added
# i =  3 # stars in isochrone: 4 96
#  need to add stars:  0 to 96
# new number of stars in isochrone under new limits 96 : 0 added
# i =  3 # stars in isochrone: 5 36
#  need to add stars:  0 to 36
# new number of stars in isochrone under new limits 36 : 0 added
# i =  3 # stars in isochrone: 6 69
#  need to add stars:  0 to 69
# new number of stars in isochrone under new limits 69 : 0 added
# i =  3 # stars in isochrone: 7 113
#  need to add stars:  0 to 113
# new number of stars in isochrone under new limits 113 : 0 added
# i =  3 # stars in isochrone: 8 296
#  need to add stars:  0 to 296
# new number of stars in isochrone under new limits 296 : 0 added
# i =  3 # stars in isochrone: 9 253
#  need to add stars:  0 to 253
# new number of stars in isochrone under new limits 253 : 0 added
# i =  3 # stars in isochrone: 10 45
#  need to add stars:  0 to 45
# new number of stars in isochrone under new limits 45 : 0 added
# i =  3 # stars in isochrone: 11 501
#  need to add stars:  0 to 501
# new number of stars in isochrone under new limits 501 : 0 added
# i =  3 # stars in isochrone: 12 2237
#  need to add stars:  0 to 2237
# new number of stars in isochrone under new limits 2237 : 0 added
# i =  3 # stars in isochrone: 13 756
#  need to add stars:  0 to 756
# new number of stars in isochrone under new limits 756 : 0 added
# i =  3 # stars in isochrone: 14 645
#  need to add stars:  0 to 645
# new number of stars in isochrone under new limits 645 : 0 added
# i =  3 # stars in isochrone: 15 3411
#  need to add stars:  0 to 3411
# new number of stars in isochrone under new limits 3411 : 0 added
# i =  4 # stars in isochrone: 0 443
#  need to add stars:  0 to 443
# new number of stars in isochrone under new limits 443 : 0 added
# i =  4 # stars in isochrone: 1 185
#  need to add stars:  0 to 185
# new number of stars in isochrone under new limits 185 : 0 added
# i =  4 # stars in isochrone: 2 128
#  need to add stars:  0 to 128
# new number of stars in isochrone under new limits 128 : 0 added
# i =  4 # stars in isochrone: 3 219
#  need to add stars:  0 to 219
# new number of stars in isochrone under new limits 219 : 0 added
# i =  4 # stars in isochrone: 4 195
#  need to add stars:  0 to 195
# new number of stars in isochrone under new limits 195 : 0 added
# i =  4 # stars in isochrone: 5 133
#  need to add stars:  0 to 133
# new number of stars in isochrone under new limits 133 : 0 added
# i =  4 # stars in isochrone: 6 204
#  need to add stars:  0 to 204
# new number of stars in isochrone under new limits 204 : 0 added
# i =  4 # stars in isochrone: 7 325
#  need to add stars:  0 to 325
# new number of stars in isochrone under new limits 325 : 0 added
# i =  4 # stars in isochrone: 8 328
#  need to add stars:  0 to 328
# new number of stars in isochrone under new limits 328 : 0 added
# i =  4 # stars in isochrone: 9 291
#  need to add stars:  0 to 291
# new number of stars in isochrone under new limits 291 : 0 added
# i =  4 # stars in isochrone: 10 86
#  need to add stars:  0 to 86
# new number of stars in isochrone under new limits 86 : 0 added
# i =  4 # stars in isochrone: 11 466
#  need to add stars:  0 to 466
# new number of stars in isochrone under new limits 466 : 0 added
# i =  4 # stars in isochrone: 12 1128
#  need to add stars:  0 to 1128
# new number of stars in isochrone under new limits 1128 : 0 added
# i =  4 # stars in isochrone: 13 971
#  need to add stars:  0 to 971
# new number of stars in isochrone under new limits 971 : 0 added
# i =  4 # stars in isochrone: 14 784
#  need to add stars:  0 to 784
# new number of stars in isochrone under new limits 784 : 0 added
# i =  4 # stars in isochrone: 15 1687
#  need to add stars:  0 to 1687
# new number of stars in isochrone under new limits 1687 : 0 added
# i =  5 # stars in isochrone: 0 522
#  need to add stars:  49 to 571
# new number of stars in isochrone under new limits 571 : 49 added
# i =  5 # stars in isochrone: 1 239
#  need to add stars:  23 to 262
# new number of stars in isochrone under new limits 262 : 23 added
# i =  5 # stars in isochrone: 2 177
#  need to add stars:  17 to 194
# new number of stars in isochrone under new limits 194 : 17 added
# i =  5 # stars in isochrone: 3 134
#  need to add stars:  13 to 147
# new number of stars in isochrone under new limits 147 : 13 added
# i =  5 # stars in isochrone: 4 165
#  need to add stars:  20 to 185
# new number of stars in isochrone under new limits 185 : 20 added
# i =  5 # stars in isochrone: 5 128
#  need to add stars:  16 to 144
# new number of stars in isochrone under new limits 144 : 16 added
# i =  5 # stars in isochrone: 6 274
#  need to add stars:  36 to 310
# new number of stars in isochrone under new limits 310 : 36 added
# i =  5 # stars in isochrone: 7 254
#  need to add stars:  34 to 288
# new number of stars in isochrone under new limits 288 : 34 added
# i =  5 # stars in isochrone: 8 330
#  need to add stars:  57 to 387
# new number of stars in isochrone under new limits 387 : 57 added
# i =  5 # stars in isochrone: 9 225
#  need to add stars:  40 to 265
# new number of stars in isochrone under new limits 265 : 40 added
# i =  5 # stars in isochrone: 10 200
#  need to add stars:  36 to 236
# new number of stars in isochrone under new limits 236 : 36 added
# i =  5 # stars in isochrone: 11 293
#  need to add stars:  54 to 347
# new number of stars in isochrone under new limits 347 : 54 added
# i =  5 # stars in isochrone: 12 700
#  need to add stars:  152 to 852
# new number of stars in isochrone under new limits 852 : 152 added
# i =  5 # stars in isochrone: 13 672
#  need to add stars:  169 to 841
# new number of stars in isochrone under new limits 841 : 169 added
# i =  5 # stars in isochrone: 14 667
#  need to add stars:  171 to 838
# new number of stars in isochrone under new limits 838 : 171 added
# i =  5 # stars in isochrone: 15 780
#  need to add stars:  199 to 979
# new number of stars in isochrone under new limits 979 : 199 added
# i =  6 # stars in isochrone: 0 758
#  need to add stars:  549 to 1307
# new number of stars in isochrone under new limits 1307 : 549 added
# i =  6 # stars in isochrone: 1 285
#  need to add stars:  242 to 527
# new number of stars in isochrone under new limits 527 : 242 added
# i =  6 # stars in isochrone: 2 276
#  need to add stars:  246 to 522
# new number of stars in isochrone under new limits 522 : 246 added
# i =  6 # stars in isochrone: 3 298
#  need to add stars:  276 to 574
# new number of stars in isochrone under new limits 574 : 276 added
# i =  6 # stars in isochrone: 4 116
#  need to add stars:  101 to 217
# new number of stars in isochrone under new limits 217 : 101 added
# i =  6 # stars in isochrone: 5 123
#  need to add stars:  112 to 235
# new number of stars in isochrone under new limits 235 : 112 added
# i =  6 # stars in isochrone: 6 194
#  need to add stars:  185 to 379
# new number of stars in isochrone under new limits 379 : 185 added
# i =  6 # stars in isochrone: 7 243
#  need to add stars:  238 to 481
# new number of stars in isochrone under new limits 481 : 238 added
# i =  6 # stars in isochrone: 8 276
#  need to add stars:  285 to 561
# new number of stars in isochrone under new limits 561 : 285 added
# i =  6 # stars in isochrone: 9 185
#  need to add stars:  200 to 385
# new number of stars in isochrone under new limits 385 : 200 added
# i =  6 # stars in isochrone: 10 188
#  need to add stars:  212 to 400
# new number of stars in isochrone under new limits 400 : 212 added
# i =  6 # stars in isochrone: 11 271
#  need to add stars:  315 to 586
# new number of stars in isochrone under new limits 586 : 315 added
# i =  6 # stars in isochrone: 12 233
#  need to add stars:  267 to 500
# new number of stars in isochrone under new limits 500 : 267 added
# i =  6 # stars in isochrone: 13 153
#  need to add stars:  181 to 334
# new number of stars in isochrone under new limits 334 : 181 added
# i =  6 # stars in isochrone: 14 185
#  need to add stars:  228 to 413
# new number of stars in isochrone under new limits 413 : 228 added
# i =  6 # stars in isochrone: 15 324
#  need to add stars:  410 to 734
# new number of stars in isochrone under new limits 734 : 410 added
# i =  7 # stars in isochrone: 0 1051
#  need to add stars:  3454 to 4505
# new number of stars in isochrone under new limits 4505 : 3454 added
# i =  7 # stars in isochrone: 1 333
#  need to add stars:  1139 to 1472
# new number of stars in isochrone under new limits 1472 : 1139 added
# i =  7 # stars in isochrone: 2 228
#  need to add stars:  848 to 1076
# new number of stars in isochrone under new limits 1076 : 848 added
# i =  7 # stars in isochrone: 3 434
#  need to add stars:  1741 to 2175
# new number of stars in isochrone under new limits 2175 : 1741 added
# i =  7 # stars in isochrone: 4 164
#  need to add stars:  531 to 695
# new number of stars in isochrone under new limits 695 : 531 added
# i =  7 # stars in isochrone: 5 146
#  need to add stars:  514 to 660
# new number of stars in isochrone under new limits 660 : 514 added
# i =  7 # stars in isochrone: 6 193
#  need to add stars:  738 to 931
# new number of stars in isochrone under new limits 931 : 738 added
# i =  7 # stars in isochrone: 7 447
#  need to add stars:  1816 to 2263
# new number of stars in isochrone under new limits 2263 : 1816 added
# i =  7 # stars in isochrone: 8 481
#  need to add stars:  1396 to 1877
# new number of stars in isochrone under new limits 1877 : 1396 added
# i =  7 # stars in isochrone: 9 209
#  need to add stars:  656 to 865
# new number of stars in isochrone under new limits 865 : 656 added
# i =  7 # stars in isochrone: 10 215
#  need to add stars:  729 to 944
# new number of stars in isochrone under new limits 944 : 729 added
# i =  7 # stars in isochrone: 11 299
#  need to add stars:  1074 to 1373
# new number of stars in isochrone under new limits 1373 : 1074 added
# i =  7 # stars in isochrone: 12 449
#  need to add stars:  1334 to 1783
# new number of stars in isochrone under new limits 1783 : 1334 added
# i =  7 # stars in isochrone: 13 235
#  need to add stars:  740 to 975
# new number of stars in isochrone under new limits 975 : 740 added
# i =  7 # stars in isochrone: 14 221
#  need to add stars:  741 to 962
# new number of stars in isochrone under new limits 962 : 741 added
# i =  7 # stars in isochrone: 15 757
#  need to add stars:  2686 to 3443
# new number of stars in isochrone under new limits 3443 : 2686 added
# (934530, 9)
# 934530 63171

# %%
np.savetxt(path_data+'/WFIfilters_extendedIsochrones_allbands_{}_M31_30_40kpc.txt'.format(WFIRSTlimits[-1]), newstars, header = '# eta, xki, R, Z, Y, J, H, F, FeH')

print ('stellar number density', len(newstars[:,0])*1.0/100, 'stars/kpc^2')
print ('stellar number density', len(newstars[:,0])*1.0/((np.max(locIn[:,0])-np.min(locIn[:,0]))*(np.max(locIn[:,1])-np.min(locIn[:,1]))), 'stars/deg^2')

print (len(oldstars[:,0]), len(newstars[:,0]))

print ('old stellar number density', len(oldstars[:,0])*1.0/100, 'stars/kpc^2')
print ('old stellar number density', len(oldstars[:,0])*1.0/((np.max(locIn[:,0])-np.min(locIn[:,0]))*(np.max(locIn[:,1])-np.min(locIn[:,1]))), 'stars/deg^2')
# Out:
# stellar number density 9345.3 stars/kpc^2
# stellar number density 475955.8875637155 stars/deg^2
# 63171 934530
# old stellar number density 631.71 stars/kpc^2
# old stellar number density 32172.973979741124 stars/deg^2

# %% [markdown]
# Do WFIRST M31 field 50-60 kpc

# %%
## Repeat as above for the field farthest out in the M31 halo
locIn = np.loadtxt(path_data+'/WFIfilters_FromPANDAS_g0limit25.5_ZRcorrection_RAdec_M31_50_60kpc_new.vot.txt', skiprows = 1, usecols = [4,5])
magsIn = np.loadtxt(path_data+'/WFIfilters_FromPANDAS_g0limit25.5_ZRcorrection_RAdec_M31_50_60kpc_new.vot.txt', skiprows = 1, usecols = [0,1])
fehIn = np.loadtxt(path_data+'/WFIfilters_FromPANDAS_g0limit25.5_ZRcorrection_RAdec_M31_50_60kpc_new.vot.txt', skiprows = 1, usecols = [6])

isos = np.loadtxt(path_data+'/WFIRST_PARSEC_isochrones_grid.txt')
dist_mod_And = 24.47 #from Ibata+2014

all_iso = []
start_feh = [0,0,0,0]
start_age = np.repeat(0,16)
j_feh = 1
j_age = 1
for i in range(len(isos[:,0])-1):
    if (isos[i+1,0] != isos[i,0]):
        start_feh[j_feh] = i+1
        j_feh = j_feh + 1
    if (isos[i+1,1] != isos[i,1]):
        start_age[j_age] = i+1
        j_age = j_age + 1


fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize = [18,6])
ax1.hist2d((magsIn[:,0]-magsIn[:,1]), magsIn[:,0], bins = 100, range = [[-1,4],[17,25]])
for j in range(15):
    ax1.scatter((isos[start_age[j]:start_age[j+1],10]-isos[start_age[j]:start_age[j+1],11]), 
            isos[start_age[j]:start_age[j+1],10] + dist_mod_And, s = 2)
ax1.scatter((isos[start_age[j+1]:,10]-isos[start_age[j+1]:,11]), 
            isos[start_age[j+1]:,10] + dist_mod_And, s = 2)
for j in range(15):
    ax1.scatter((isos[start_age[j]:start_age[j+1],10]-isos[start_age[j]:start_age[j+1],11]), 
            isos[start_age[j]:start_age[j+1],10] + 18, s = 2)
ax1.scatter((isos[start_age[j+1]:,10]-isos[start_age[j+1]:,11]), 
            isos[start_age[j+1]:,10] + 18, s = 2)
ax1.set_xlabel('R - Z')
ax1.set_ylabel('R')
ax1.axis([-1,4,25,17])
ax2.hist2d((magsIn[:,0]-magsIn[:,1]), magsIn[:,1], bins = 100, range = [[-1,4],[17,25]])
for j in range(15):
    ax2.scatter((isos[start_age[j]:start_age[j+1],10]-isos[start_age[j]:start_age[j+1],11]), 
            isos[start_age[j]:start_age[j+1],11] + dist_mod_And, s = 2)
ax2.scatter((isos[start_age[j+1]:,10]-isos[start_age[j+1]:,11]), 
            isos[start_age[j+1]:,11] + dist_mod_And, s = 2)
for j in range(15):
    ax2.scatter((isos[start_age[j]:start_age[j+1],10]-isos[start_age[j]:start_age[j+1],11]), 
            isos[start_age[j]:start_age[j+1],11] + 12, s = 2)
ax2.scatter((isos[start_age[j+1]:,10]-isos[start_age[j+1]:,11]), 
            isos[start_age[j+1]:,11] + 12, s = 2)
for j in range(15):
    ax2.scatter((isos[start_age[j]:start_age[j+1],10]-isos[start_age[j]:start_age[j+1],11]), 
            isos[start_age[j]:start_age[j+1],11] + 10, s = 2)
ax2.scatter((isos[start_age[j+1]:,10]-isos[start_age[j+1]:,11]), 
            isos[start_age[j+1]:,11] + 10, s = 2)
for j in range(15):
    ax2.scatter((isos[start_age[j]:start_age[j+1],10]-isos[start_age[j]:start_age[j+1],11]), 
            isos[start_age[j]:start_age[j+1],11] + 18, s = 2)
ax2.scatter((isos[start_age[j+1]:,10]-isos[start_age[j+1]:,11]), 
            isos[start_age[j+1]:,11] + 18, s = 2)
ax2.set_xlabel('R - Z')
ax2.set_ylabel('Z')
ax2.axis([-1,4,25,17])
ax3.hist2d(magsIn[:,0], magsIn[:,1], bins = 50, range = [[17,25],[17,25]])
for j in range(15):
    ax3.scatter(isos[start_age[j]:start_age[j+1],10] + dist_mod_And, isos[start_age[j]:start_age[j+1],11] + dist_mod_And, s = 2)
ax3.scatter(isos[start_age[j+1]:,10] + dist_mod_And, isos[start_age[j+1]:,11]  + dist_mod_And, s = 2)
for j in range(15):
    ax3.scatter(isos[start_age[j]:start_age[j+1],10] + 18, isos[start_age[j]:start_age[j+1],11] + 18, s = 2)
ax3.scatter(isos[start_age[j+1]:,10] + 18, isos[start_age[j+1]:,11]  + 18, s = 2)
ax3.set_xlabel('R')
ax3.set_ylabel('Z')
ax3.axis([25,17,25,17])
# Out:
# (25.0, 17.0, 25.0, 17.0)

# %%
match = np.zeros(len(magsIn[:,0]))
matchFeH = np.zeros(len(magsIn[:,0]))
matchAge = np.zeros(len(magsIn[:,0]))
matchgal = np.zeros(len(magsIn[:,0]))
print (len(match), len(isos[:,13]))
range1 = np.max(np.concatenate((magsIn[:,1], isos[:,11] + dist_mod_And,
                                isos[:,11] + 8, isos[:,11] + 10, isos[:,11] + 12, isos[:,11] + 14,
                                isos[:,11] + 16, isos[:,11] + 18, isos[:,11] + 20), axis=0))
- np.min(np.concatenate((magsIn[:,1], isos[:,11] + dist_mod_And,
                         isos[:,11] + 8, isos[:,11] + 10, isos[:,11] + 12, isos[:,11] + 14,
                         isos[:,11] + 16, isos[:,11] + 18, isos[:,11] + 20), axis=0))
range2 = np.max(np.concatenate((magsIn[:,0]-magsIn[:,1], isos[:,10]-isos[:,11], isos[:,10]-isos[:,11], 
                                isos[:,10]-isos[:,11], isos[:,10]-isos[:,11], isos[:,10]-isos[:,11], 
                                isos[:,10]-isos[:,11], isos[:,10]-isos[:,11], isos[:,10]-isos[:,11]), axis=0))
- np.min(np.concatenate((magsIn[:,0]-magsIn[:,1], isos[:,10]-isos[:,11], isos[:,10]-isos[:,11], 
                         isos[:,10]-isos[:,11], isos[:,10]-isos[:,11], isos[:,10]-isos[:,11],
                         isos[:,10]-isos[:,11], isos[:,10]-isos[:,11], isos[:,10]-isos[:,11]), axis=0))
for i in range(len(magsIn[:,0])):
    rescale_dist1 = (magsIn[i,1] - np.concatenate((isos[:,11] + dist_mod_And,
                                isos[:,11] + 8, isos[:,11] + 10, isos[:,11] + 12, isos[:,11] + 14,
                                isos[:,11] + 16, isos[:,11] + 18, isos[:,11] + 20), axis=0)) / range1
    rescale_dist2 = ((magsIn[i,0]-magsIn[i,1]) - np.concatenate((isos[:,10]-isos[:,11], isos[:,10]-isos[:,11], 
                                isos[:,10]-isos[:,11], isos[:,10]-isos[:,11], isos[:,10]-isos[:,11], 
                                isos[:,10]-isos[:,11], isos[:,10]-isos[:,11], isos[:,10]-isos[:,11]), axis=0)) / range2
    match[i] = np.argmin(np.sqrt(rescale_dist1**2 + rescale_dist2**2))
    if np.logical_and(match[i] < start_age[1], match[i] >= start_age[0]):
        matchFeH[i] = isos[np.asarray(start_feh),0][0]
        matchAge[i] = isos[np.asarray(start_age),1][0]
        matchgal[i] = 0
    elif np.logical_and(match[i] < start_age[2], match[i] >= start_age[1]):
        matchFeH[i] = isos[np.asarray(start_feh),0][0]
        matchAge[i] = isos[np.asarray(start_age),1][1]
        matchgal[i] = 0
    elif np.logical_and(match[i] < start_age[3], match[i] >= start_age[2]):
        matchFeH[i] = isos[np.asarray(start_feh),0][0]
        matchAge[i] = isos[np.asarray(start_age),1][2]
        matchgal[i] = 0
    elif np.logical_and(match[i] < start_age[4], match[i] >= start_age[3]):
        matchFeH[i] = isos[np.asarray(start_feh),0][0]
        matchAge[i] = isos[np.asarray(start_age),1][3]
        matchgal[i] = 0
    elif np.logical_and(match[i] < start_age[5], match[i] >= start_age[4]):
        matchFeH[i] = isos[np.asarray(start_feh),0][1]
        matchAge[i] = isos[np.asarray(start_age),1][0]
        matchgal[i] = 0
    elif np.logical_and(match[i] < start_age[6], match[i] >= start_age[5]):
        matchFeH[i] = isos[np.asarray(start_feh),0][1]
        matchAge[i] = isos[np.asarray(start_age),1][1]
        matchgal[i] = 0
    elif np.logical_and(match[i] < start_age[7], match[i] >= start_age[6]):
        matchFeH[i] = isos[np.asarray(start_feh),0][1]
        matchAge[i] = isos[np.asarray(start_age),1][2]
        matchgal[i] = 0
    elif np.logical_and(match[i] < start_age[8], match[i] >= start_age[7]):
        matchFeH[i] = isos[np.asarray(start_feh),0][1]
        matchAge[i] = isos[np.asarray(start_age),1][3]
        matchgal[i] = 0
    elif np.logical_and(match[i] < start_age[9], match[i] >= start_age[8]):
        matchFeH[i] = isos[np.asarray(start_feh),0][2]
        matchAge[i] = isos[np.asarray(start_age),1][0]
        matchgal[i] = 0
    elif np.logical_and(match[i] < start_age[10], match[i] >= start_age[9]):
        matchFeH[i] = isos[np.asarray(start_feh),0][2]
        matchAge[i] = isos[np.asarray(start_age),1][1]
        matchgal[i] = 0
    elif np.logical_and(match[i] < start_age[11], match[i] >= start_age[10]):
        matchFeH[i] = isos[np.asarray(start_feh),0][2]
        matchAge[i] = isos[np.asarray(start_age),1][2]
        matchgal[i] = 0
    elif np.logical_and(match[i] < start_age[12], match[i] >= start_age[11]):
        matchFeH[i] = isos[np.asarray(start_feh),0][2]
        matchAge[i] = isos[np.asarray(start_age),1][3]
        matchgal[i] = 0
    elif np.logical_and(match[i] < start_age[13], match[i] >= start_age[12]):
        matchFeH[i] = isos[np.asarray(start_feh),0][3]
        matchAge[i] = isos[np.asarray(start_age),1][0]
        matchgal[i] = 0
    elif np.logical_and(match[i] < start_age[14], match[i] >= start_age[13]):
        matchFeH[i] = isos[np.asarray(start_feh),0][3]
        matchAge[i] = isos[np.asarray(start_age),1][1]
        matchgal[i] = 0
    elif np.logical_and(match[i] < start_age[15], match[i] >= start_age[14]):
        matchFeH[i] = isos[np.asarray(start_feh),0][3]
        matchAge[i] = isos[np.asarray(start_age),1][2]
        matchgal[i] = 0
    elif np.logical_and(match[i] < len(isos[:,13]), match[i] >= start_age[15]):
        matchFeH[i] = isos[np.asarray(start_feh),0][3]
        matchAge[i] = isos[np.asarray(start_age),1][3]
        matchgal[i] = 0
    elif match[i] > len(isos[:,13]) + start_age[0]:
        MWmatch = match[i] % len(isos[:,13])
        if np.logical_and(MWmatch < start_age[1], MWmatch > start_age[0]):
            matchFeH[i] = isos[np.asarray(start_feh),0][0]
            matchAge[i] = isos[np.asarray(start_age),1][0]
            matchgal[i] = np.round(match[i] / len(isos[:,13])).astype('int')
        elif np.logical_and(MWmatch < start_age[2], MWmatch > start_age[1]):
            matchFeH[i] = isos[np.asarray(start_feh),0][0]
            matchAge[i] = isos[np.asarray(start_age),1][1]
            matchgal[i] = np.round(match[i] / len(isos[:,13])).astype('int')
        elif np.logical_and(MWmatch < start_age[3], MWmatch > start_age[2]):
            matchFeH[i] = isos[np.asarray(start_feh),0][0]
            matchAge[i] = isos[np.asarray(start_age),1][2]
            matchgal[i] = np.round(match[i] / len(isos[:,13])).astype('int')
        elif np.logical_and(MWmatch < start_age[4], MWmatch > start_age[3]):
            matchFeH[i] = isos[np.asarray(start_feh),0][0]
            matchAge[i] = isos[np.asarray(start_age),1][3]
            matchgal[i] = np.round(match[i] / len(isos[:,13])).astype('int')
        elif np.logical_and(MWmatch < start_age[5], MWmatch > start_age[4]):
            matchFeH[i] = isos[np.asarray(start_feh),0][1]
            matchAge[i] = isos[np.asarray(start_age),1][0]
            matchgal[i] = np.round(match[i] / len(isos[:,13])).astype('int')
        elif np.logical_and(MWmatch < start_age[6], MWmatch > start_age[5]):
            matchFeH[i] = isos[np.asarray(start_feh),0][1]
            matchAge[i] = isos[np.asarray(start_age),1][1]
            matchgal[i] = np.round(match[i] / len(isos[:,13])).astype('int')
        elif np.logical_and(MWmatch < start_age[7], MWmatch > start_age[6]):
            matchFeH[i] = isos[np.asarray(start_feh),0][1]
            matchAge[i] = isos[np.asarray(start_age),1][2]
            matchgal[i] = np.round(match[i] / len(isos[:,13])).astype('int')
        elif np.logical_and(MWmatch < start_age[8], MWmatch > start_age[7]):
            matchFeH[i] = isos[np.asarray(start_feh),0][1]
            matchAge[i] = isos[np.asarray(start_age),1][3]
            matchgal[i] = np.round(match[i] / len(isos[:,13])).astype('int')
        elif np.logical_and(MWmatch < start_age[9], MWmatch > start_age[8]):
            matchFeH[i] = isos[np.asarray(start_feh),0][2]
            matchAge[i] = isos[np.asarray(start_age),1][0]
            matchgal[i] = np.round(match[i] / len(isos[:,13])).astype('int')
        elif np.logical_and(MWmatch < start_age[10], MWmatch > start_age[9]):
            matchFeH[i] = isos[np.asarray(start_feh),0][2]
            matchAge[i] = isos[np.asarray(start_age),1][1]
            matchgal[i] = np.round(match[i] / len(isos[:,13])).astype('int')
        elif np.logical_and(MWmatch < start_age[11], MWmatch > start_age[10]):
            matchFeH[i] = isos[np.asarray(start_feh),0][2]
            matchAge[i] = isos[np.asarray(start_age),1][2]
            matchgal[i] = np.round(match[i] / len(isos[:,13])).astype('int')
        elif np.logical_and(MWmatch < start_age[12], MWmatch > start_age[11]):
            matchFeH[i] = isos[np.asarray(start_feh),0][2]
            matchAge[i] = isos[np.asarray(start_age),1][3]
            matchgal[i] = np.round(match[i] / len(isos[:,13])).astype('int')
        elif np.logical_and(MWmatch < start_age[13], MWmatch > start_age[12]):
            matchFeH[i] = isos[np.asarray(start_feh),0][3]
            matchAge[i] = isos[np.asarray(start_age),1][0]
            matchgal[i] = np.round(match[i] / len(isos[:,13])).astype('int')
        elif np.logical_and(MWmatch < start_age[14], MWmatch > start_age[13]):
            matchFeH[i] = isos[np.asarray(start_feh),0][3]
            matchAge[i] = isos[np.asarray(start_age),1][1]
            matchgal[i] = np.round(match[i] / len(isos[:,13])).astype('int')
        elif np.logical_and(MWmatch < start_age[15], MWmatch > start_age[14]):
            matchFeH[i] = isos[np.asarray(start_feh),0][3]
            matchAge[i] = isos[np.asarray(start_age),1][2]
            matchgal[i] = np.round(match[i] / len(isos[:,13])).astype('int')
        elif np.logical_and(MWmatch < len(isos[:,13]), match[i] >= len(isos[:,13]) + start_age[15]):
            matchFeH[i] = isos[np.asarray(start_feh),0][3]
            matchAge[i] = isos[np.asarray(start_age),1][3]
            matchgal[i] = np.round(match[i] / len(isos[:,13])).astype('int')

        
print ("number of stars matched to FeH of isochrones:")
print (isos[np.asarray(start_feh),0][0], np.sum(matchFeH == isos[np.asarray(start_feh),0][0]))
print (isos[np.asarray(start_feh),0][1], np.sum(matchFeH == isos[np.asarray(start_feh),0][1]))
print (isos[np.asarray(start_feh),0][2], np.sum(matchFeH == isos[np.asarray(start_feh),0][2]))
print (isos[np.asarray(start_feh),0][3], np.sum(matchFeH == isos[np.asarray(start_feh),0][3]))
print ("number of stars matched to Age of isochrones:")
print (10.0**isos[np.asarray(start_age),1][0]/1e9, np.sum(matchAge == isos[np.asarray(start_age),1][0]))
print (10.0**isos[np.asarray(start_age),1][1]/1e9, np.sum(matchAge == isos[np.asarray(start_age),1][1]))
print (10.0**isos[np.asarray(start_age),1][2]/1e9, np.sum(matchAge == isos[np.asarray(start_age),1][2]))
print (10.0**isos[np.asarray(start_age),1][3]/1e9, np.sum(matchAge == isos[np.asarray(start_age),1][3]))

print ("galaxy")
print ("MW", np.sum(matchgal >= 1))
print ("M31", np.sum(matchgal == 0))
# Out:
# 67498 3886
# number of stars matched to FeH of isochrones:
# 4.916e-05 12792
# 0.00049127 5005
# 0.0048287 15601
# 0.041517 32900
# number of stars matched to Age of isochrones:
# 8.491804750363144 19708
# 9.506047936562808 12034
# 10.49542428652324 10005
# 11.508003889444357 24551
# galaxy
# MW 47024
# M31 20474

# %%
fig, axes = plt.subplots(4,4, figsize = [20,20])
for j in range(16):
    axes[j%4,int(j/4)].hist2d((magsIn[np.logical_and(matchFeH == isos[np.asarray(start_feh),0][int(j/4)], 
                                      matchAge == isos[np.asarray(start_age),1][j%4]),0]
                -magsIn[np.logical_and(matchFeH == isos[np.asarray(start_feh),0][int(j/4)], 
                                      matchAge == isos[np.asarray(start_age),1][j%4]),1]), 
               magsIn[np.logical_and(matchFeH == isos[np.asarray(start_feh),0][int(j/4)], 
                                      matchAge == isos[np.asarray(start_age),1][j%4]),1], 
               bins = 50, range = [[-1,4],[17,25]])
    if j == 15:
        axes[j%4,int(j/4)].scatter((isos[start_age[j]:,10]-isos[start_age[j]:,11]), 
            isos[start_age[j]:,11]  + dist_mod_And, s = 2)
        axes[j%4,int(j/4)].scatter((isos[start_age[j]:,10]-isos[start_age[j]:,11]), 
            isos[start_age[j]:,11]  + 8, s = 2)
        axes[j%4,int(j/4)].scatter((isos[start_age[j]:,10]-isos[start_age[j]:,11]), 
            isos[start_age[j]:,11]  + 10, s = 2)
        axes[j%4,int(j/4)].scatter((isos[start_age[j]:,10]-isos[start_age[j]:,11]), 
            isos[start_age[j]:,11]  + 12, s = 2)
        axes[j%4,int(j/4)].scatter((isos[start_age[j]:,10]-isos[start_age[j]:,11]), 
            isos[start_age[j]:,11]  + 14, s = 2)        
        axes[j%4,int(j/4)].scatter((isos[start_age[j]:,10]-isos[start_age[j]:,11]), 
            isos[start_age[j]:,11]  + 16, s = 2)        
        axes[j%4,int(j/4)].scatter((isos[start_age[j]:,10]-isos[start_age[j]:,11]), 
            isos[start_age[j]:,11]  + 18, s = 2)       
        axes[j%4,int(j/4)].scatter((isos[start_age[j]:,10]-isos[start_age[j]:,11]), 
            isos[start_age[j]:,11]  + 20, s = 2)       
    else:
        axes[j%4,int(j/4)].scatter((isos[start_age[j]:start_age[j+1],10]-isos[start_age[j]:start_age[j+1],11]), 
            isos[start_age[j]:start_age[j+1],11] + dist_mod_And, s = 2)
        axes[j%4,int(j/4)].scatter((isos[start_age[j]:start_age[j+1],10]-isos[start_age[j]:start_age[j+1],11]), 
            isos[start_age[j]:start_age[j+1],11] + 8, s = 2)
        axes[j%4,int(j/4)].scatter((isos[start_age[j]:start_age[j+1],10]-isos[start_age[j]:start_age[j+1],11]), 
            isos[start_age[j]:start_age[j+1],11] + 10, s = 2)
        axes[j%4,int(j/4)].scatter((isos[start_age[j]:start_age[j+1],10]-isos[start_age[j]:start_age[j+1],11]), 
            isos[start_age[j]:start_age[j+1],11] + 12, s = 2)
        axes[j%4,int(j/4)].scatter((isos[start_age[j]:start_age[j+1],10]-isos[start_age[j]:start_age[j+1],11]), 
            isos[start_age[j]:start_age[j+1],11] + 14, s = 2)
        axes[j%4,int(j/4)].scatter((isos[start_age[j]:start_age[j+1],10]-isos[start_age[j]:start_age[j+1],11]), 
            isos[start_age[j]:start_age[j+1],11] + 16, s = 2)
        axes[j%4,int(j/4)].scatter((isos[start_age[j]:start_age[j+1],10]-isos[start_age[j]:start_age[j+1],11]), 
            isos[start_age[j]:start_age[j+1],11] + 18, s = 2)
        axes[j%4,int(j/4)].scatter((isos[start_age[j]:start_age[j+1],10]-isos[start_age[j]:start_age[j+1],11]), 
            isos[start_age[j]:start_age[j+1],11] + 20, s = 2)
    axes[j%4,int(j/4)].text(2,23.5,'[Fe/H] = %0.1e' %(isos[np.asarray(start_feh),0][int(j/4)]), color = 'white')
    axes[j%4,int(j/4)].text(2,24,'age = %0.1f Gyr' %(10.0**isos[np.asarray(start_age),1][j%4]/1e9), color = 'white')
    axes[j%4,int(j/4)].text(2,24.5,'# stars = %d' %(np.sum(np.logical_and(matchFeH == isos[np.asarray(start_feh),0][int(j/4)], 
                                      matchAge == isos[np.asarray(start_age),1][j%4]))), color = 'white')
    axes[j%4,int(j/4)].text(2,25,'# stars And = %d' %(np.sum(np.logical_and(np.logical_and(matchFeH == isos[np.asarray(start_feh),0][int(j/4)], 
                                      matchAge == isos[np.asarray(start_age),1][j%4]), matchgal == 0))), color = 'white')
    axes[j%4,int(j/4)].set_xlabel('R - Z')
    axes[j%4,int(j/4)].set_ylabel('Z')
    axes[j%4,int(j/4)].axis([-1,4,25,17])
    
def kde(x, x_num, x_grid, bandwidth=0.2, **kwargs):
    """Kernel Density Estimation with Scipy"""
    x_tot = np.asarray([])
    for i in range(len(x)):
        x_tot = np.concatenate((x_tot, np.repeat(x[i], int(x_num[i]))), axis = 0)
    kde = gaussian_kde(x_tot)
    return kde.evaluate(x_grid)


def generate_rand_from_pdf(pdf, x_grid, num):
    cdf = np.cumsum(pdf)
    cdf = cdf / cdf[-1]
    values = np.random.rand(num)
    value_bins = np.searchsorted(cdf, values)
    random_from_cdf = x_grid[value_bins]
    return random_from_cdf
    
wfirst_mags = np.loadtxt(path_data+'/WFIRST_PARSEC_isochrones_grid.txt', skiprows = 12, usecols = [10,11,12,13,14,15])
oldstars = np.concatenate((locIn, np.reshape(magsIn, (len(magsIn),2)), np.reshape(fehIn, (len(fehIn),1))), axis=1)
newstars = np.asarray([])
for i in range(8): #MW inner halo, MW outer halo, M31
    if i == 0: dist_mod = dist_mod_And
    elif i >= 1: dist_mod = 6 + 2*i
    for j in range(16):
        start_isochrone = start_age[j]
        if j == len(start_age)-1:
            end_isochrone = len(wfirst_mags[:,0])-1
        else:
            end_isochrone = start_age[j+1]-1
        inter_Rmags = interp.interp1d(wfirst_mags[start_isochrone:end_isochrone,1], 
                        wfirst_mags[start_isochrone:end_isochrone,0], assume_sorted = False, fill_value = "extrapolate")
        inter_Ymags = interp.interp1d(wfirst_mags[start_isochrone:end_isochrone,1], 
                        wfirst_mags[start_isochrone:end_isochrone,2], assume_sorted = False, fill_value = "extrapolate")
        inter_Jmags = interp.interp1d(wfirst_mags[start_isochrone:end_isochrone,1], 
                        wfirst_mags[start_isochrone:end_isochrone,3], assume_sorted = False, fill_value = "extrapolate")
        inter_Hmags = interp.interp1d(wfirst_mags[start_isochrone:end_isochrone,1], 
                        wfirst_mags[start_isochrone:end_isochrone,4], assume_sorted = False, fill_value = "extrapolate")
        inter_Fmags = interp.interp1d(wfirst_mags[start_isochrone:end_isochrone,1], 
                        wfirst_mags[start_isochrone:end_isochrone,5], assume_sorted = False, fill_value = "extrapolate")
        lumfunc = np.loadtxt(path_data+'/WFIRST_PARSEC_lumfunc_isochrone%d_allbands.txt' %j)
        
        numstars = np.sum(np.logical_and(np.logical_and(matchFeH == isos[np.asarray(start_feh),0][int(j/4)],
                                      matchAge == isos[np.asarray(start_age),1][j%4]), matchgal == i))
        print ('i = ', i, '# stars in isochrone:', j, numstars)
        feh = isos[np.asarray(start_feh),0][int(j/4)]
        limits = [np.max(magsIn[:,0]), np.max(magsIn[:,1])]
        if numstars > 0:
            numunderlim = np.asarray([np.sum(lumfunc[lumfunc[:,0] + dist_mod < limits[0],1]), 
                np.sum(lumfunc[lumfunc[:,2] + dist_mod < limits[1],3])])
            #print 'number of 1e5 stars luminosity function under old limits of', limits, ':', numunderlim
            newnumunderlim = np.asarray([np.sum(lumfunc[lumfunc[:,0] + dist_mod < WFIRSTlimits[0],1]), 
                np.sum(lumfunc[lumfunc[:,2] + dist_mod < WFIRSTlimits[1],3])])
            #print 'number of 1e5 stars luminosity function under new limits of', WFIRSTlimits, ':',  newnumunderlim
            newnumstars = np.round(numstars*newnumunderlim[1]*1.0/numunderlim[1]).astype('int')
            addstars = newnumstars - numstars
            print (" need to add stars: ", addstars, "to", newnumstars)
            x_grid_Z = np.linspace(np.min(wfirst_mags[start_isochrone:end_isochrone,1] + dist_mod), 
                                   np.min([WFIRSTlimits[1], np.max(wfirst_mags[start_isochrone:end_isochrone,1]) + dist_mod]), 
                                   newnumstars)
            kdepdf_Z = kde(lumfunc[lumfunc[:,2] + dist_mod < WFIRSTlimits[1],2] + dist_mod,
                       lumfunc[lumfunc[:,2] + dist_mod < WFIRSTlimits[1],3], x_grid_Z)
            random_Z = generate_rand_from_pdf(kdepdf_Z, x_grid_Z, newnumstars)
            random_R = inter_Rmags(random_Z - dist_mod) + dist_mod
            random_H = inter_Hmags(random_Z - dist_mod) + dist_mod
            random_Y = inter_Ymags(random_Z - dist_mod) + dist_mod
            random_J = inter_Jmags(random_Z - dist_mod) + dist_mod
            random_F = inter_Fmags(random_Z - dist_mod) + dist_mod
            random_xki = np.random.uniform(low = np.min(locIn[:,0]), high = np.max(locIn[:,0]), size = newnumstars)
            random_eta = np.random.uniform(low = np.min(locIn[:,1]), high = np.max(locIn[:,1]), size = newnumstars)
            if newstars.size == 0:
                newstars = np.concatenate((np.reshape(random_xki, (len(random_xki),1)), 
                                        np.reshape(random_eta, (len(random_eta),1)), 
                                        np.reshape(random_R, (len(random_R),1)), 
                                        np.reshape(random_Z, (len(random_Z),1)), 
                                        np.reshape(random_Y, (len(random_Y),1)), 
                                        np.reshape(random_J, (len(random_J),1)),
                                        np.reshape(random_H, (len(random_H),1)), 
                                        np.reshape(random_F, (len(random_F),1)),
                                        np.reshape(np.repeat(np.log10(feh*1.0/0.0152), len(random_xki))
                                                , (len(random_xki),1))), axis = 1)
            else:
                newstars = np.concatenate((newstars, np.concatenate((np.reshape(random_xki, (len(random_xki),1)), 
                                        np.reshape(random_eta, (len(random_eta),1)), 
                                        np.reshape(random_R, (len(random_R),1)), 
                                        np.reshape(random_Z, (len(random_Z),1)), 
                                        np.reshape(random_Y, (len(random_Y),1)), 
                                        np.reshape(random_J, (len(random_J),1)),
                                        np.reshape(random_H, (len(random_H),1)), 
                                        np.reshape(random_F, (len(random_F),1)),
                                        np.reshape(np.repeat(np.log10(feh*1.0/0.0152), len(random_xki))
                                                , (len(random_xki),1))), axis = 1)), axis = 0)
            print ('new number of stars in isochrone under new limits', newnumstars, ':', addstars, "added")

print (np.shape(newstars))
print (len(newstars[:,0]), len(oldstars[:,0]))
# Out:
# i =  0 # stars in isochrone: 0 1027
#  need to add stars:  34249 to 35276
# new number of stars in isochrone under new limits 35276 : 34249 added
# i =  0 # stars in isochrone: 1 919
#  need to add stars:  33595 to 34514
# new number of stars in isochrone under new limits 34514 : 33595 added
# i =  0 # stars in isochrone: 2 1213
#  need to add stars:  44241 to 45454
# new number of stars in isochrone under new limits 45454 : 44241 added
# i =  0 # stars in isochrone: 3 2853
#  need to add stars:  104221 to 107074
# new number of stars in isochrone under new limits 107074 : 104221 added
# i =  0 # stars in isochrone: 4 335
#  need to add stars:  12409 to 12744
# new number of stars in isochrone under new limits 12744 : 12409 added
# i =  0 # stars in isochrone: 5 206
#  need to add stars:  7812 to 8018
# new number of stars in isochrone under new limits 8018 : 7812 added
# i =  0 # stars in isochrone: 6 243
#  need to add stars:  9242 to 9485
# new number of stars in isochrone under new limits 9485 : 9242 added
# i =  0 # stars in isochrone: 7 397
#  need to add stars:  15336 to 15733
# new number of stars in isochrone under new limits 15733 : 15336 added
# i =  0 # stars in isochrone: 8 1358
#  need to add stars:  47914 to 49272
# new number of stars in isochrone under new limits 49272 : 47914 added
# i =  0 # stars in isochrone: 9 957
#  need to add stars:  34809 to 35766
# new number of stars in isochrone under new limits 35766 : 34809 added
# i =  0 # stars in isochrone: 10 1212
#  need to add stars:  46152 to 47364
# new number of stars in isochrone under new limits 47364 : 46152 added
# i =  0 # stars in isochrone: 11 3441
#  need to add stars:  131983 to 135424
# new number of stars in isochrone under new limits 135424 : 131983 added
# i =  0 # stars in isochrone: 12 2482
#  need to add stars:  92757 to 95239
# new number of stars in isochrone under new limits 95239 : 92757 added
# i =  0 # stars in isochrone: 13 1612
#  need to add stars:  66637 to 68249
# new number of stars in isochrone under new limits 68249 : 66637 added
# i =  0 # stars in isochrone: 14 650
#  need to add stars:  26241 to 26891
# new number of stars in isochrone under new limits 26891 : 26241 added
# i =  0 # stars in isochrone: 15 369
#  need to add stars:  14192 to 14561
# new number of stars in isochrone under new limits 14561 : 14192 added
# i =  1 # stars in isochrone: 0 14
#  need to add stars:  0 to 14
# new number of stars in isochrone under new limits 14 : 0 added
# i =  1 # stars in isochrone: 1 9
#  need to add stars:  0 to 9
# new number of stars in isochrone under new limits 9 : 0 added
# i =  1 # stars in isochrone: 2 9
#  need to add stars:  0 to 9
# new number of stars in isochrone under new limits 9 : 0 added
# i =  1 # stars in isochrone: 3 18
#  need to add stars:  0 to 18
# new number of stars in isochrone under new limits 18 : 0 added
# i =  1 # stars in isochrone: 4 12
#  need to add stars:  0 to 12
# new number of stars in isochrone under new limits 12 : 0 added
# i =  1 # stars in isochrone: 5 0
# i =  1 # stars in isochrone: 6 7
#  need to add stars:  0 to 7
# new number of stars in isochrone under new limits 7 : 0 added
# i =  1 # stars in isochrone: 7 13
#  need to add stars:  0 to 13
# new number of stars in isochrone under new limits 13 : 0 added
# i =  1 # stars in isochrone: 8 248
#  need to add stars:  0 to 248
# new number of stars in isochrone under new limits 248 : 0 added
# i =  1 # stars in isochrone: 9 0
# i =  1 # stars in isochrone: 10 0
# i =  1 # stars in isochrone: 11 0
# i =  1 # stars in isochrone: 12 0
# i =  1 # stars in isochrone: 13 0
# i =  1 # stars in isochrone: 14 0
# i =  1 # stars in isochrone: 15 0
# i =  2 # stars in isochrone: 0 51
#  need to add stars:  0 to 51
# new number of stars in isochrone under new limits 51 : 0 added
# i =  2 # stars in isochrone: 1 30
#  need to add stars:  0 to 30
# new number of stars in isochrone under new limits 30 : 0 added
# i =  2 # stars in isochrone: 2 12
#  need to add stars:  0 to 12
# new number of stars in isochrone under new limits 12 : 0 added
# i =  2 # stars in isochrone: 3 23
#  need to add stars:  0 to 23
# new number of stars in isochrone under new limits 23 : 0 added
# i =  2 # stars in isochrone: 4 31
#  need to add stars:  0 to 31
# new number of stars in isochrone under new limits 31 : 0 added
# i =  2 # stars in isochrone: 5 7
#  need to add stars:  0 to 7
# new number of stars in isochrone under new limits 7 : 0 added
# i =  2 # stars in isochrone: 6 35
#  need to add stars:  0 to 35
# new number of stars in isochrone under new limits 35 : 0 added
# i =  2 # stars in isochrone: 7 30
#  need to add stars:  0 to 30
# new number of stars in isochrone under new limits 30 : 0 added
# i =  2 # stars in isochrone: 8 529
#  need to add stars:  0 to 529
# new number of stars in isochrone under new limits 529 : 0 added
# i =  2 # stars in isochrone: 9 84
#  need to add stars:  0 to 84
# new number of stars in isochrone under new limits 84 : 0 added
# i =  2 # stars in isochrone: 10 10
#  need to add stars:  0 to 10
# new number of stars in isochrone under new limits 10 : 0 added
# i =  2 # stars in isochrone: 11 589
#  need to add stars:  0 to 589
# new number of stars in isochrone under new limits 589 : 0 added
# i =  2 # stars in isochrone: 12 515
#  need to add stars:  0 to 515
# new number of stars in isochrone under new limits 515 : 0 added
# i =  2 # stars in isochrone: 13 246
#  need to add stars:  0 to 246
# new number of stars in isochrone under new limits 246 : 0 added
# i =  2 # stars in isochrone: 14 60
#  need to add stars:  0 to 60
# new number of stars in isochrone under new limits 60 : 0 added
# i =  2 # stars in isochrone: 15 1103
#  need to add stars:  0 to 1103
# new number of stars in isochrone under new limits 1103 : 0 added
# i =  3 # stars in isochrone: 0 90
#  need to add stars:  0 to 90
# new number of stars in isochrone under new limits 90 : 0 added
# i =  3 # stars in isochrone: 1 61
#  need to add stars:  0 to 61
# new number of stars in isochrone under new limits 61 : 0 added
# i =  3 # stars in isochrone: 2 30
#  need to add stars:  0 to 30
# new number of stars in isochrone under new limits 30 : 0 added
# i =  3 # stars in isochrone: 3 63
#  need to add stars:  0 to 63
# new number of stars in isochrone under new limits 63 : 0 added
# i =  3 # stars in isochrone: 4 108
#  need to add stars:  0 to 108
# new number of stars in isochrone under new limits 108 : 0 added
# i =  3 # stars in isochrone: 5 48
#  need to add stars:  0 to 48
# new number of stars in isochrone under new limits 48 : 0 added
# i =  3 # stars in isochrone: 6 70
#  need to add stars:  0 to 70
# new number of stars in isochrone under new limits 70 : 0 added
# i =  3 # stars in isochrone: 7 100
#  need to add stars:  0 to 100
# new number of stars in isochrone under new limits 100 : 0 added
# i =  3 # stars in isochrone: 8 438
#  need to add stars:  0 to 438
# new number of stars in isochrone under new limits 438 : 0 added
# i =  3 # stars in isochrone: 9 326
#  need to add stars:  0 to 326
# new number of stars in isochrone under new limits 326 : 0 added
# i =  3 # stars in isochrone: 10 55
#  need to add stars:  0 to 55
# new number of stars in isochrone under new limits 55 : 0 added
# i =  3 # stars in isochrone: 11 631
#  need to add stars:  0 to 631
# new number of stars in isochrone under new limits 631 : 0 added
# i =  3 # stars in isochrone: 12 2657
#  need to add stars:  0 to 2657
# new number of stars in isochrone under new limits 2657 : 0 added
# i =  3 # stars in isochrone: 13 945
#  need to add stars:  0 to 945
# new number of stars in isochrone under new limits 945 : 0 added
# i =  3 # stars in isochrone: 14 742
#  need to add stars:  0 to 742
# new number of stars in isochrone under new limits 742 : 0 added
# i =  3 # stars in isochrone: 15 4102
#  need to add stars:  0 to 4102
# new number of stars in isochrone under new limits 4102 : 0 added
# i =  4 # stars in isochrone: 0 420
#  need to add stars:  0 to 420
# new number of stars in isochrone under new limits 420 : 0 added
# i =  4 # stars in isochrone: 1 197
#  need to add stars:  0 to 197
# new number of stars in isochrone under new limits 197 : 0 added
# i =  4 # stars in isochrone: 2 113
#  need to add stars:  0 to 113
# new number of stars in isochrone under new limits 113 : 0 added
# i =  4 # stars in isochrone: 3 159
#  need to add stars:  0 to 159
# new number of stars in isochrone under new limits 159 : 0 added
# i =  4 # stars in isochrone: 4 177
#  need to add stars:  0 to 177
# new number of stars in isochrone under new limits 177 : 0 added
# i =  4 # stars in isochrone: 5 128
#  need to add stars:  0 to 128
# new number of stars in isochrone under new limits 128 : 0 added
# i =  4 # stars in isochrone: 6 177
#  need to add stars:  0 to 177
# new number of stars in isochrone under new limits 177 : 0 added
# i =  4 # stars in isochrone: 7 331
#  need to add stars:  0 to 331
# new number of stars in isochrone under new limits 331 : 0 added
# i =  4 # stars in isochrone: 8 356
#  need to add stars:  0 to 356
# new number of stars in isochrone under new limits 356 : 0 added
# i =  4 # stars in isochrone: 9 337
#  need to add stars:  0 to 337
# new number of stars in isochrone under new limits 337 : 0 added
# i =  4 # stars in isochrone: 10 118
#  need to add stars:  0 to 118
# new number of stars in isochrone under new limits 118 : 0 added
# i =  4 # stars in isochrone: 11 548
#  need to add stars:  0 to 548
# new number of stars in isochrone under new limits 548 : 0 added
# i =  4 # stars in isochrone: 12 1420
#  need to add stars:  0 to 1420
# new number of stars in isochrone under new limits 1420 : 0 added
# i =  4 # stars in isochrone: 13 1205
#  need to add stars:  0 to 1205
# new number of stars in isochrone under new limits 1205 : 0 added
# i =  4 # stars in isochrone: 14 939
#  need to add stars:  0 to 939
# new number of stars in isochrone under new limits 939 : 0 added
# i =  4 # stars in isochrone: 15 2092
#  need to add stars:  0 to 2092
# new number of stars in isochrone under new limits 2092 : 0 added
# i =  5 # stars in isochrone: 0 737
#  need to add stars:  56 to 793
# new number of stars in isochrone under new limits 793 : 56 added
# i =  5 # stars in isochrone: 1 276
#  need to add stars:  21 to 297
# new number of stars in isochrone under new limits 297 : 21 added
# i =  5 # stars in isochrone: 2 184
#  need to add stars:  15 to 199
# new number of stars in isochrone under new limits 199 : 15 added
# i =  5 # stars in isochrone: 3 152
#  need to add stars:  12 to 164
# new number of stars in isochrone under new limits 164 : 12 added
# i =  5 # stars in isochrone: 4 209
#  need to add stars:  18 to 227
# new number of stars in isochrone under new limits 227 : 18 added
# i =  5 # stars in isochrone: 5 158
#  need to add stars:  14 to 172
# new number of stars in isochrone under new limits 172 : 14 added
# i =  5 # stars in isochrone: 6 269
#  need to add stars:  24 to 293
# new number of stars in isochrone under new limits 293 : 24 added
# i =  5 # stars in isochrone: 7 366
#  need to add stars:  33 to 399
# new number of stars in isochrone under new limits 399 : 33 added
# i =  5 # stars in isochrone: 8 347
#  need to add stars:  43 to 390
# new number of stars in isochrone under new limits 390 : 43 added
# i =  5 # stars in isochrone: 9 203
#  need to add stars:  25 to 228
# new number of stars in isochrone under new limits 228 : 25 added
# i =  5 # stars in isochrone: 10 224
#  need to add stars:  29 to 253
# new number of stars in isochrone under new limits 253 : 29 added
# i =  5 # stars in isochrone: 11 318
#  need to add stars:  42 to 360
# new number of stars in isochrone under new limits 360 : 42 added
# i =  5 # stars in isochrone: 12 881
#  need to add stars:  170 to 1051
# new number of stars in isochrone under new limits 1051 : 170 added
# i =  5 # stars in isochrone: 13 891
#  need to add stars:  175 to 1066
# new number of stars in isochrone under new limits 1066 : 175 added
# i =  5 # stars in isochrone: 14 795
#  need to add stars:  158 to 953
# new number of stars in isochrone under new limits 953 : 158 added
# i =  5 # stars in isochrone: 15 942
#  need to add stars:  189 to 1131
# new number of stars in isochrone under new limits 1131 : 189 added
# i =  6 # stars in isochrone: 0 818
#  need to add stars:  507 to 1325
# new number of stars in isochrone under new limits 1325 : 507 added
# i =  6 # stars in isochrone: 1 404
#  need to add stars:  251 to 655
# new number of stars in isochrone under new limits 655 : 251 added
# i =  6 # stars in isochrone: 2 327
#  need to add stars:  212 to 539
# new number of stars in isochrone under new limits 539 : 212 added
# i =  6 # stars in isochrone: 3 351
#  need to add stars:  236 to 587
# new number of stars in isochrone under new limits 587 : 236 added
# i =  6 # stars in isochrone: 4 129
#  need to add stars:  97 to 226
# new number of stars in isochrone under new limits 226 : 97 added
# i =  6 # stars in isochrone: 5 136
#  need to add stars:  107 to 243
# new number of stars in isochrone under new limits 243 : 107 added
# i =  6 # stars in isochrone: 6 173
#  need to add stars:  142 to 315
# new number of stars in isochrone under new limits 315 : 142 added
# i =  6 # stars in isochrone: 7 270
#  need to add stars:  228 to 498
# new number of stars in isochrone under new limits 498 : 228 added
# i =  6 # stars in isochrone: 8 267
#  need to add stars:  219 to 486
# new number of stars in isochrone under new limits 486 : 219 added
# i =  6 # stars in isochrone: 9 211
#  need to add stars:  179 to 390
# new number of stars in isochrone under new limits 390 : 179 added
# i =  6 # stars in isochrone: 10 238
#  need to add stars:  211 to 449
# new number of stars in isochrone under new limits 449 : 211 added
# i =  6 # stars in isochrone: 11 332
#  need to add stars:  342 to 674
# new number of stars in isochrone under new limits 674 : 342 added
# i =  6 # stars in isochrone: 12 298
#  need to add stars:  284 to 582
# new number of stars in isochrone under new limits 582 : 284 added
# i =  6 # stars in isochrone: 13 161
#  need to add stars:  158 to 319
# new number of stars in isochrone under new limits 319 : 158 added
# i =  6 # stars in isochrone: 14 209
#  need to add stars:  212 to 421
# new number of stars in isochrone under new limits 421 : 212 added
# i =  6 # stars in isochrone: 15 354
#  need to add stars:  369 to 723
# new number of stars in isochrone under new limits 723 : 369 added
# i =  7 # stars in isochrone: 0 1013
#  need to add stars:  2733 to 3746
# new number of stars in isochrone under new limits 3746 : 2733 added
# i =  7 # stars in isochrone: 1 429
#  need to add stars:  1325 to 1754
# new number of stars in isochrone under new limits 1754 : 1325 added
# i =  7 # stars in isochrone: 2 274
#  need to add stars:  917 to 1191
# new number of stars in isochrone under new limits 1191 : 917 added
# i =  7 # stars in isochrone: 3 516
#  need to add stars:  1855 to 2371
# new number of stars in isochrone under new limits 2371 : 1855 added
# i =  7 # stars in isochrone: 4 162
#  need to add stars:  433 to 595
# new number of stars in isochrone under new limits 595 : 433 added
# i =  7 # stars in isochrone: 5 137
#  need to add stars:  395 to 532
# new number of stars in isochrone under new limits 532 : 395 added
# i =  7 # stars in isochrone: 6 190
#  need to add stars:  590 to 780
# new number of stars in isochrone under new limits 780 : 590 added
# i =  7 # stars in isochrone: 7 351
#  need to add stars:  1154 to 1505
# new number of stars in isochrone under new limits 1505 : 1154 added
# i =  7 # stars in isochrone: 8 507
#  need to add stars:  1344 to 1851
# new number of stars in isochrone under new limits 1851 : 1344 added
# i =  7 # stars in isochrone: 9 161
#  need to add stars:  460 to 621
# new number of stars in isochrone under new limits 621 : 460 added
# i =  7 # stars in isochrone: 10 152
#  need to add stars:  468 to 620
# new number of stars in isochrone under new limits 620 : 468 added
# i =  7 # stars in isochrone: 11 287
#  need to add stars:  932 to 1219
# new number of stars in isochrone under new limits 1219 : 932 added
# i =  7 # stars in isochrone: 12 381
#  need to add stars:  955 to 1336
# new number of stars in isochrone under new limits 1336 : 955 added
# i =  7 # stars in isochrone: 13 207
#  need to add stars:  547 to 754
# new number of stars in isochrone under new limits 754 : 547 added
# i =  7 # stars in isochrone: 14 238
#  need to add stars:  667 to 905
# new number of stars in isochrone under new limits 905 : 667 added
# i =  7 # stars in isochrone: 15 752
#  need to add stars:  2217 to 2969
# new number of stars in isochrone under new limits 2969 : 2217 added
# (803089, 9)
# 803089 67498

# %%
np.savetxt(path_data+'/WFIfilters_extendedIsochrones_allbands_{}_M31_50_60kpc.txt'.format(WFIRSTlimits[-1]), newstars, header = '# eta, xki, R, Z, Y, J, H, F, FeH')

print ('stellar number density', len(newstars[:,0])*1.0/100, 'stars/kpc^2')
print ('stellar number density', len(newstars[:,0])*1.0/((np.max(locIn[:,0])-np.min(locIn[:,0]))*(np.max(locIn[:,1])-np.min(locIn[:,1]))), 'stars/deg^2')

print (len(oldstars[:,0]), len(newstars[:,0]))

print ('old stellar number density', len(oldstars[:,0])*1.0/100, 'stars/kpc^2')
print ('old stellar number density', len(oldstars[:,0])*1.0/((np.max(locIn[:,0])-np.min(locIn[:,0]))*(np.max(locIn[:,1])-np.min(locIn[:,1]))), 'stars/deg^2')
# Out:
# stellar number density 8030.89 stars/kpc^2
# stellar number density 379850.4794193994 stars/deg^2
# 67498 803089
# old stellar number density 674.98 stars/kpc^2
# old stellar number density 31925.66161390658 stars/deg^2

# %%
## add RA and dec; these are independent of the eta and xki assigned above. This is done per field.
## So even though we have both for every star they are not correlated (both are used for separate things so it's ok)

# read in for one field
RAdec = np.genfromtxt(path_data+'/WFIfilters_FromPANDAS_g0limit25.5_ZRcorrection_RAdec_M31_30_40kpc_new.vot.txt', skip_header = 1, usecols = [2,3],dtype='str')
data = np.loadtxt(path_data+'/WFIfilters_extendedIsochrones_allbands_{}_M31_30_40kpc.txt'.format(WFIRSTlimits[-1]))
from astropy.coordinates import SkyCoord
import astropy.units as u
c = SkyCoord(ra = RAdec[:,0], dec = RAdec[:,1], frame = 'icrs', unit = (u.hourangle, u.deg))
random_ra = np.random.uniform(low = np.min(c.ra.degree), high = np.max(c.ra.degree), size = len(data[:,0]))
random_dec = np.random.uniform(low = np.min(c.dec.degree), high = np.max(c.dec.degree), size = len(data[:,0]))
random_skypos = SkyCoord(ra = random_ra, dec = random_dec, frame = 'icrs', unit = (u.deg, u.deg))
#coord = random_skypos.to_string('hmsdms', sep=':')
coord = np.concatenate((np.reshape(random_skypos.ra.degree, (len(random_skypos.ra.degree),1)), 
                        np.reshape(random_skypos.dec.degree, (len(random_skypos.dec.degree),1))), axis = 1)
tab = np.concatenate((data, np.reshape(coord, (len(coord), 2))), axis = 1)
nms  = ('eta', 'xki', 'R', 'Z', 'Y', 'J', 'H', 'F', 'FeH_phot', 'RA', 'dec')
fmt  = {'eta': '%15.7f', 'xki': '%15.7f', 'R': '%15.7f', 'Z': '%15.7f', 'Y': '%15.7f', 
            'J': '%15.7f', 'H': '%15.7f', 'F': '%15.7f', 'FeH_phot': '%15.7f', 'RA': '%15.7f', 'dec': '%15.7f'}
from astropy.table import Table
from astropy.io import ascii
t    = Table(tab, names=nms)
## print out for this field
outfile = path_data+'/WFIfilters_extendedIsochrones_allbandsRAdec_{}_M31_30_40kpc.txt'.format(WFIRSTlimits[-1])
ascii.write(t, outfile, format='fixed_width', delimiter='',overwrite = True)

# %%
##compare fields of the randomly assigned RA and dec to uniform random RA and dec

fig, (ax1, ax2) = plt.subplots(1,2, figsize = [12,6])
ax1.scatter(random_ra, random_dec, s = 0.01)
ax2.scatter(random_skypos.ra.degree, random_skypos.dec.degree, s = 0.01)
plt.show()

# %%
# read in for one field
RAdec = np.genfromtxt(path_data+'/WFIfilters_FromPANDAS_g0limit25.5_ZRcorrection_RAdec_M31_10_20kpc_new.vot.txt', skip_header = 1, usecols = [2,3],dtype='str')
data = np.loadtxt(path_data+'/WFIfilters_extendedIsochrones_allbands_{}_M31_10_20kpc.txt'.format(WFIRSTlimits[-1]))
from astropy.coordinates import SkyCoord
import astropy.units as u
c = SkyCoord(ra = RAdec[:,0], dec = RAdec[:,1], frame = 'icrs', unit = (u.hourangle, u.deg))
random_ra = np.random.uniform(low = np.min(c.ra.degree), high = np.max(c.ra.degree), size = len(data[:,0]))
random_dec = np.random.uniform(low = np.min(c.dec.degree), high = np.max(c.dec.degree), size = len(data[:,0]))
random_skypos = SkyCoord(ra = random_ra, dec = random_dec, frame = 'icrs', unit = (u.deg, u.deg))
#coord = random_skypos.to_string('hmsdms', sep=':')
coord = np.concatenate((np.reshape(random_skypos.ra.degree, (len(random_skypos.ra.degree),1)), 
                        np.reshape(random_skypos.dec.degree, (len(random_skypos.dec.degree),1))), axis = 1)
tab = np.concatenate((data, np.reshape(coord, (len(coord), 2))), axis = 1)
nms  = ('eta', 'xki', 'R', 'Z', 'Y', 'J', 'H', 'F', 'FeH_phot', 'RA', 'dec')
fmt  = {'eta': '%15.7f', 'xki': '%15.7f', 'R': '%15.7f', 'Z': '%15.7f', 'Y': '%15.7f', 
            'J': '%15.7f', 'H': '%15.7f', 'F': '%15.7f', 'FeH_phot': '%15.7f', 'RA': '%15.7f', 'dec': '%15.7f'}
from astropy.table import Table
from astropy.io import ascii
t    = Table(tab, names=nms)
## print out for this field
outfile = path_data+'/WFIfilters_extendedIsochrones_allbandsRAdec_{}_M31_10_20kpc.txt'.format(WFIRSTlimits[-1])
ascii.write(t, outfile, format='fixed_width', delimiter='',overwrite = True)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-28-f486e734f7bb> in <module>
#      20 ## print out for this field
#      21 outfile = path_data+'/WFIfilters_extendedIsochrones_allbandsRAdec_{}_M31_10_20kpc.txt'.format(WFIRSTlimits[-1])
# ---> 22 ascii.write(t, outfile, format='fixed_width', delimiter='',overwrite = True)
#
# /opt/anaconda3/lib/python3.8/site-packages/astropy/io/ascii/ui.py in write(table, output, format, Writer, fast_writer, overwrite, **kwargs)
#     862         # auto-translation.
#     863         output = open(output, 'w', newline='')
# --> 864         output.write(outstr)
#     865         output.write(os.linesep)
#     866         output.close()
#
# OSError: [Errno 28] No space left on device

# %%
# read in for one field
RAdec = np.genfromtxt(path_data+'/WFIfilters_FromPANDAS_g0limit25.5_ZRcorrection_RAdec_M31_50_60kpc_new.vot.txt', skip_header = 1, usecols = [2,3],dtype='str')
data = np.loadtxt(path_data+'/WFIfilters_extendedIsochrones_allbands_{}_M31_50_60kpc.txt'.format(WFIRSTlimits[-1]))
from astropy.coordinates import SkyCoord
import astropy.units as u
c = SkyCoord(ra = RAdec[:,0], dec = RAdec[:,1], frame = 'icrs', unit = (u.hourangle, u.deg))
random_ra = np.random.uniform(low = np.min(c.ra.degree), high = np.max(c.ra.degree), size = len(data[:,0]))
random_dec = np.random.uniform(low = np.min(c.dec.degree), high = np.max(c.dec.degree), size = len(data[:,0]))
random_skypos = SkyCoord(ra = random_ra, dec = random_dec, frame = 'icrs', unit = (u.deg, u.deg))
#coord = random_skypos.to_string('hmsdms', sep=':')
coord = np.concatenate((np.reshape(random_skypos.ra.degree, (len(random_skypos.ra.degree),1)), 
                        np.reshape(random_skypos.dec.degree, (len(random_skypos.dec.degree),1))), axis = 1)
tab = np.concatenate((data, np.reshape(coord, (len(coord), 2))), axis = 1)
nms  = ('eta', 'xki', 'R', 'Z', 'Y', 'J', 'H', 'F', 'FeH_phot', 'RA', 'dec')
fmt  = {'eta': '%15.7f', 'xki': '%15.7f', 'R': '%15.7f', 'Z': '%15.7f', 'Y': '%15.7f', 
            'J': '%15.7f', 'H': '%15.7f', 'F': '%15.7f', 'FeH_phot': '%15.7f', 'RA': '%15.7f', 'dec': '%15.7f'}
from astropy.table import Table
from astropy.io import ascii
t    = Table(tab, names=nms)
## print out for this field
outfile = path_data+'/WFIfilters_extendedIsochrones_allbandsRAdec_{}_M31_50_60kpc.txt'.format(WFIRSTlimits[-1])
ascii.write(t, outfile, format='fixed_width', delimiter='',overwrite = True)

# %%
#fig, (ax1, ax2) = plt.subplots(1,2, figsize = [12,6])
#ax1.scatter(random_ra, random_dec, s = 0.01)
#ax2.scatter(random_skypos.ra.degree, random_skypos.dec.degree, s = 0.01)
#plt.show()

# %%
fig, ax=plt.subplots()
for j in range(15):
    lumfunc = np.loadtxt(path_data+'/WFIRST_PARSEC_lumfunc_isochrone%d_allbands.txt' %j)
    x_grid_Z = np.linspace(np.min(wfirst_mags[start_isochrone:end_isochrone,1] + dist_mod), 
                                   np.min([WFIRSTlimits[1], np.max(wfirst_mags[start_isochrone:end_isochrone,1]) + dist_mod]), 
                                   newnumstars)
    kdepdf_Z = kde(lumfunc[lumfunc[:,2] + dist_mod < WFIRSTlimits[1],2] + dist_mod,
                       lumfunc[lumfunc[:,2] + dist_mod < WFIRSTlimits[1],3], x_grid_Z)
    ax.step(x_grid_Z, kdepdf_Z)
ax.axvline(28.54, color='k', linestyle='--')
ax.set(xlabel='Z mag', ylabel='Number Fraction')
